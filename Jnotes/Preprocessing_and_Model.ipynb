# %% [markdown]
# ### NISHANTH IRUTHAYARAJ
# Matric. No: 1522044

# %% [markdown]
# **Data Preprocessing**

# %%
import pandas as pd
import numpy as np

#Reading files and Correcting Timestamp#
c_heads = ['Time', 'Device', 'e1' , 'e2' , 'e3' , 'e4' , 'e5' , 'e6' ,'Label']
df_sub1_esense = pd.read_csv('eSense_sbj1.csv', names = c_heads)
df_sub1_esense['Time'] = pd.to_datetime(df_sub1_esense['Time'], unit = 'ms') + pd.Timedelta('02:00:00')
df_sub1_esense = df_sub1_esense.set_index('Time').resample('10L', offset = 4000000).first().interpolate()
df_sub1_esense = df_sub1_esense.sort_index()

df_sub2_esense = pd.read_csv('eSense_sbj2.csv', names = c_heads)
df_sub2_esense['Time'] = pd.to_datetime(df_sub2_esense['Time'], unit = 'ms') + pd.Timedelta('02:00:00')
df_sub2_esense = df_sub2_esense.set_index('Time').resample('10L', offset = 4000000).first().interpolate()
df_sub2_esense = df_sub2_esense.sort_index()

# %%
#Data Interpolating and Upsampling
#Subject 1 ankle
df_layup1_ankle = pd.read_csv('layup_sbj1_ankle.csv', index_col = 0, comment= ';')
df_layup1_ankle.index = pd.date_range(start = '2021-04-14 18:22:13.554', periods = df_layup1_ankle.shape[0], freq = "10.869565L")
df_layup1_ankle = df_layup1_ankle.resample('10L', offset = 4000000).first().interpolate()

df_movements1_ankle_1 = pd.read_csv('movements_sbj1_ankle_1.csv', index_col = 0, comment= ';')
df_movements1_ankle_1.index = pd.date_range(start = '2021-04-14 18:42:32.024', periods = df_movements1_ankle_1.shape[0], freq = "10.869565L")
df_movements1_ankle_1 = df_movements1_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_shooting1_ankle_1 = pd.read_csv('shooting_sbj1_ankle.csv', index_col = 0, comment= ';')
df_shooting1_ankle_1.index = pd.date_range(start = '2021-04-14 18:12:54.024', periods = df_shooting1_ankle_1.shape[0], freq = "10.869565L")
df_shooting1_ankle_1 = df_shooting1_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_sub1_ankle = pd.concat([df_layup1_ankle,df_movements1_ankle_1,df_shooting1_ankle_1])
df_sub1_ankle = df_sub1_ankle.set_axis(['a1', 'a2', 'a3'], axis = 'columns')
#df_sub1_ankle = df_sub1_ankle.sort_index()

#Subject 2 ankle
df_dribbling2_ankle = pd.read_csv('dribbling_sbj2_ankle.csv', index_col = 0, comment= ';')
df_dribbling2_ankle.index = pd.date_range(start = '2021-04-14 19:26:42.914', periods = df_dribbling2_ankle.shape[0], freq = "10.869565L")
df_dribbling2_ankle = df_dribbling2_ankle.resample('10L', offset = 4000000).first().interpolate()

df_layup2_ankle = pd.read_csv('layup_sbj2_ankle.csv', index_col = 0, comment= ';')
df_layup2_ankle.index = pd.date_range(start = '2021-04-14 19:16:25.794', periods = df_layup2_ankle.shape[0], freq = "10.869565L")
df_layup2_ankle = df_layup2_ankle.resample('10L', offset = 4000000).first().interpolate()

df_movements2_ankle_1 = pd.read_csv('movements_sbj2_ankle_1.csv', index_col = 0, comment= ';') 
df_movements2_ankle_1.index = pd.date_range(start = '2021-04-14 19:36:19.244', periods = df_movements2_ankle_1.shape[0], freq = "10.869565L")
df_movements2_ankle_1 = df_movements2_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_shooting2_ankle_1 = pd.read_csv('shooting_sbj2_ankle_1.csv', index_col = 0, comment= ';')
df_shooting2_ankle_1.index = pd.date_range(start = '2021-04-14 18:55:50.364', periods = df_shooting2_ankle_1.shape[0], freq = "10.869565L")
df_shooting2_ankle_1 = df_shooting2_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_sub2_ankle = pd.concat([df_dribbling2_ankle, df_layup2_ankle, df_movements2_ankle_1, df_shooting2_ankle_1])
df_sub2_ankle = df_sub2_ankle.set_axis(['a1','a2','a3'], axis = 'columns')
#df_sub2_ankle = df_sub2_ankle.sort_index()

# %%
#Subject 1 wrist
df_layup1_wrist = pd.read_csv('layup_sbj1_wrist.csv', index_col = 0, comment= ';')
df_layup1_wrist.index = pd.date_range(start = '2021-04-14 18:22:52.524', periods = df_layup1_wrist.shape[0], freq = "10.869565L")
df_layup1_wrist = df_layup1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_movements1_wrist = pd.read_csv('movements_sbj1_wrist.csv', index_col = 0, comment= ';')
df_movements1_wrist.index = pd.date_range(start = '2021-04-14 18:42:05.244', periods = df_movements1_wrist.shape[0], freq = "10.869565L")
df_movements1_wrist = df_movements1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_shooting1_wrist = pd.read_csv('shooting_sbj1_wrist.csv', index_col = 0, comment= ';')
df_shooting1_wrist.index = pd.date_range(start = '2021-04-14 18:13:12.834', periods = df_shooting1_wrist.shape[0], freq = "10.869565L")
df_shooting1_wrist = df_shooting1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_sub1_wrist = pd.concat([df_layup1_wrist, df_movements1_wrist, df_shooting1_wrist])
df_sub1_wrist = df_sub1_wrist.set_axis(['w1','w2','w3'], axis = 'columns')
#df_sub1_wrist = df_sub1_wrist.sort_index()

#Subject 2 wrist
df_dribbling2_wrist = pd.read_csv('dribbling_sbj2_wrist.csv', index_col = 0, comment= ';')
df_dribbling2_wrist.index = pd.date_range(start = '2021-04-14 19:26:24.464', periods = df_dribbling2_wrist.shape[0], freq = "10.869565L")
df_dribbling2_wrist = df_dribbling2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_layup2_wrist = pd.read_csv('layup_sbj2_wrist.csv', index_col = 0, comment= ';')
df_layup2_wrist.index = pd.date_range(start = '2021-04-14 19:16:05.604', periods = df_layup2_wrist.shape[0], freq = "10.869565L")
df_layup2_wrist = df_layup2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_movements2_wrist = pd.read_csv('movements_sbj2_wrist.csv', index_col = 0, comment= ';') 
df_movements2_wrist.index = pd.date_range(start = '2021-04-14 19:36:45.074', periods = df_movements2_wrist.shape[0], freq = "10.869565L")
df_movements2_wrist = df_movements2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_shooting2_wrist = pd.read_csv('shooting_sbj2_wrist.csv', index_col = 0, comment= ';')
df_shooting2_wrist.index = pd.date_range(start = '2021-04-14 18:56:21.474', periods = df_shooting2_wrist.shape[0], freq = "10.869565L")
df_shooting2_wrist = df_shooting2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_sub2_wrist = pd.concat([df_dribbling2_wrist, df_layup2_wrist, df_movements2_wrist, df_shooting2_wrist])
df_sub2_wrist = df_sub2_wrist.set_axis(['w1','w2','w3'], axis = 'columns')
#df_sub2_wrist = df_sub2_wrist.sort_index()

# %%
#Merging and Normalising each 
df_sub1 = df_sub1_esense.merge(df_sub1_ankle, left_index=True, right_index=True)
df_1 = df_sub1.merge(df_sub1_wrist, left_index=True, right_index=True)
df_1 = (df_1 - df_1.mean()) / df_1.std()
df_1 = df_1.drop(['Device'], axis = 1)

df_sub2 = df_sub2_esense.merge(df_sub2_ankle, left_index=True, right_index=True)
df_2 = df_sub2.merge(df_sub2_wrist, left_index=True, right_index=True)
df_2 = (df_2 - df_2.mean()) / df_2.std()
df_2 = df_2.drop(['Device'], axis = 1)

# %%
#Finding Samples for Time Intersection
intersection_1 = [df_1.index.isin(df_1.between_time('18:23:14', '18:25:28').index),
                  df_1.index.isin(df_1.between_time('18:45:17', '18:47:16').index),
                  df_1.index.isin(df_1.between_time('18:13:25', '18:15:47').index),
                  df_1.index.isin(df_1.between_time('18:42:48', '18:45:17').index)]
activity_1 = ['layup', 'running', 'shooting', 'walking']
df_1['Label'] = np.select(intersection_1, activity_1, 'Null')
df_1['Subjects'] = 'Subject1'
df_1 = df_1[['e1','e2','e3','e4','e5','e6','a1','a2','a3','w1','w2','w3','Label','Subjects']]

intersection_2 = [df_2.index.isin(df_2.between_time('19:26:58', '19:29:59').index), 
                  df_2.index.isin(df_2.between_time('19:17:35', '19:20:14').index),
                  df_2.index.isin(df_2.between_time('19:39:47', '19:41:55').index),
                  df_2.index.isin(df_2.between_time('19:00:14', '19:02:12').index),
                  df_2.index.isin(df_2.between_time('19:37:15', '19:39:46').index)]
activity_2 = ['dribbling', 'layup', 'running', 'shooting', 'walking']
df_2['Label'] = np.select(intersection_2, activity_2, 'Null')
df_2['Subjects'] = 'Subject2'
df_2 = df_2[['e1','e2','e3','e4','e5','e6','a1','a2','a3','w1','w2','w3','Label','Subjects']]

df = pd.concat([df_1, df_2])
df.reset_index(drop=True, inplace=True)
df.to_csv('df_activity.csv')

# %%
#Importing and Label Encoding 
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('df_activity.csv', index_col = 0)
label = LabelEncoder()
df['Label'] = label.fit_transform(df['Label'].values)

df_new = df.drop(['Subjects'], axis = 1)

df_s1 = df.loc[df['Subjects'] == 'Subject1']
d1_s1 = df_s1.drop(['Subjects'], axis = 1)

df_s2 = df.loc[df['Subjects'] == 'Subject2']
d2_s2 = df_s2.drop(['Subjects'], axis = 1)

window_length = 100
overlap = 60

# %%
#Sliding Window
def sliding_window_samples(data, samples_per_window, overlap_ratio):
    """
    Return a sliding window measured in number of samples over a data array.

    :param data: input array, can be numpy or pandas dataframe
    :param samples_per_window: window length as number of samples per window
    :param overlap_ratio: overlap is meant as percentage and should be an integer value
    :return: tuple of windows and indices
    """
    windows = []
    indices = []
    curr = 0
    win_len = samples_per_window
    if overlap_ratio is not None:
        overlapping_elements = int((overlap_ratio / 100) * (win_len))
        if overlapping_elements >= win_len:
            print('Number of overlapping elements exceeds window size.')
            return
    while curr < len(data) - win_len:
        windows.append(data[curr:curr + win_len])
        indices.append([curr, curr + win_len])
        curr = curr + win_len - overlapping_elements
    try:
        result_windows = np.array(windows)
        result_indices = np.array(indices)
    except:
        result_windows = np.empty(shape=(len(windows), win_len, data.shape[1]), dtype=object)
        result_indices = np.array(indices)
        for i in range(0, len(windows)):
            result_windows[i] = windows[i]
            result_indices[i] = indices[i]

    return result_windows, result_indices

# %%
#Reshaping the features and target for giving input to the model
#It takes the most common values in each window for the target after appling sliding window and 
#also returns the reshaped array. Parameters assumed f=features and t=target
def reshape(f,t):
    axis = 1
    x_new = np.reshape(f, (f.shape[0], -1))
    y, indices = np.unique(t, return_inverse=True)
    y_new = y[np.argmax(np.apply_along_axis(np.bincount, axis, indices.reshape(t.shape),None, np.max(indices) + 1), axis=axis)]
    return np.asarray(x_new), np.asarray(y_new)

# %% [markdown]
# **KNN Model**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold, cross_val_score

def model_KNN(features, target, score):
    knn = KNeighborsClassifier(n_neighbors = 3,  p = 2)
    kfold = KFold(n_splits = 10, random_state=42, shuffle=True)
    scores = cross_val_score(knn, features, target, cv = kfold, scoring = score, n_jobs = -1)
    return scores.mean()

# %%
#Normal Cross Validation for KNN
df_1, df_2 = sliding_window_samples(df_new, window_length, overlap)
data = np.array(df_1, dtype = float)
X_data = data[:, : ,0:12]
y_data = data[:, : , 12]
X_n, y_n = reshape(X_data, y_data)
accuracy_n = model_KNN(X_n, y_n, 'accuracy')
precision_n = model_KNN(X_n, y_n, 'precision_weighted')
recall_n =  model_KNN(X_n, y_n, 'recall_weighted')
f1_n = model_KNN(X_n, y_n, 'f1_weighted')

#Per Participant Cross Validation for KNN
#Subject 1
df_sub1, df_subj_1 = sliding_window_samples(d1_s1, window_length, overlap)
data_s1 = np.array(df_sub1, dtype = float)
X_s1 = data_s1[:, : ,0:12]
y_s1 = data_s1[:, : , 12]
X_sub1, y_sub1 = reshape(X_s1, y_s1)
accuracy_s1 = model_KNN(X_sub1, y_sub1, 'accuracy')
precision_s1 = model_KNN(X_sub1, y_sub1, 'precision_weighted')
recall_s1 = model_KNN(X_sub1, y_sub1, 'recall_weighted')
f1_s1 = model_KNN(X_sub1, y_sub1, 'f1_weighted')

#Subject 2
df_sub2, df_subj_2 = sliding_window_samples(d2_s2, window_length, overlap)
data_s2 = np.array(df_sub2, dtype = float)
X_s2 = data_s2[:, : ,0:12]
y_s2 = data_s2[:, : , 12]
X_sub2, y_sub2 = reshape(X_s2, y_s2)
accuracy_s2 = model_KNN(X_sub2, y_sub2, 'accuracy')
precision_s2 = model_KNN(X_sub2, y_sub2, 'precision_weighted')
recall_s2 = model_KNN(X_sub2, y_sub2, 'recall_weighted')
f1_s2 = model_KNN(X_sub2, y_sub2, 'f1_weighted')

# %% [markdown]
# **LSTM model**

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, LSTM
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import f1_score, confusion_matrix
from pandas import DataFrame

def model_LSTM(X,y,k):
    scores=[]
    f1=[]
    matrix=[]
    c_matrix = 0
    split = 1
    skf = StratifiedKFold(n_splits=k,random_state=None, shuffle=False)
    for train_index, test_index in skf.split(X, y):
        #print("TRAIN:", train_index, "TEST:", test_index)
        print('Fold number : ------------- : ', split)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        #Model architecture            
        model = Sequential()
        model.add(LSTM(units=32,input_shape=[X_train.shape[1], X_train.shape[2]], activation = 'relu', return_sequences = True))
        model.add(Dropout(rate=0.1))
        model.add(Flatten())
        model.add(Dense(units=360, activation='relu'))
        model.add(Dropout(rate=0.3))
        model.add(Dense(units=6, activation='softmax'))

        #Compile the model
        model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        #Fit data to model
        history = model.fit(X_train,y_train,epochs=10, validation_data=(X_test,y_test),verbose=1)
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        
        #Genarate Metrics
        scores.append(model.evaluate(X_test,y_test))
        f1.append(f1_score(y_test, y_pred, average='weighted'))
        matrix.append(confusion_matrix(y_test, y_pred))
        split+=1        
    return np.array(scores), np.array(f1), np.array(matrix)

# %%
#Normal Validation
df_1, df_2 = sliding_window_samples(df_new, window_length, overlap)
data = np.array(df_1, dtype = float)

X_n = data[:, : ,0:12]
y_n = data[:, : , 12]
X_dummy, y_n = reshape(X_n, y_n)
fold_n=10
scores_n, f1_scores_n, matrix_n = model_LSTM(X_n,y_n,fold_n)
acc_scores_n = scores_n[:,-1]
c_matrix_n = matrix_n[-1]
# Out:
# Fold number : ------------- :  1
# Epoch 1/10
# 115/115 [==============================] - 5s 30ms/step - loss: 0.7605 - accuracy: 0.7633 - val_loss: 0.7098 - val_accuracy: 0.8020
# Epoch 2/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2848 - accuracy: 0.9074 - val_loss: 0.9071 - val_accuracy: 0.7800
# Epoch 3/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1927 - accuracy: 0.9395 - val_loss: 0.8650 - val_accuracy: 0.8044
# Epoch 4/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1285 - accuracy: 0.9556 - val_loss: 0.9344 - val_accuracy: 0.7824
# Epoch 5/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0920 - accuracy: 0.9698 - val_loss: 1.0370 - val_accuracy: 0.8215
# Epoch 6/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0623 - accuracy: 0.9801 - val_loss: 1.2115 - val_accuracy: 0.7873
# Epoch 7/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0590 - accuracy: 0.9798 - val_loss: 1.1576 - val_accuracy: 0.8093
# Epoch 8/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0305 - accuracy: 0.9888 - val_loss: 1.3060 - val_accuracy: 0.8117
# Epoch 9/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0237 - accuracy: 0.9937 - val_loss: 1.3926 - val_accuracy: 0.7995
# Epoch 10/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0319 - accuracy: 0.9894 - val_loss: 1.2235 - val_accuracy: 0.8166
# 13/13 [==============================] - 0s 10ms/step - loss: 1.2235 - accuracy: 0.8166
# Fold number : ------------- :  2
# Epoch 1/10
# 115/115 [==============================] - 6s 38ms/step - loss: 0.8073 - accuracy: 0.7335 - val_loss: 0.3330 - val_accuracy: 0.8995
# Epoch 2/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.3548 - accuracy: 0.8775 - val_loss: 0.2724 - val_accuracy: 0.8971
# Epoch 3/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.3787 - accuracy: 0.8998 - val_loss: 0.2922 - val_accuracy: 0.8995
# Epoch 4/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.1942 - accuracy: 0.9338 - val_loss: 0.2678 - val_accuracy: 0.9118
# Epoch 5/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.1484 - accuracy: 0.9480 - val_loss: 0.3450 - val_accuracy: 0.9142
# Epoch 6/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.1160 - accuracy: 0.9583 - val_loss: 0.2138 - val_accuracy: 0.9314
# Epoch 7/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0879 - accuracy: 0.9695 - val_loss: 0.2357 - val_accuracy: 0.9167
# Epoch 8/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0720 - accuracy: 0.9782 - val_loss: 0.2403 - val_accuracy: 0.9240
# Epoch 9/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0558 - accuracy: 0.9848 - val_loss: 0.2255 - val_accuracy: 0.9363
# Epoch 10/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0581 - accuracy: 0.9826 - val_loss: 0.1853 - val_accuracy: 0.9461
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1853 - accuracy: 0.9461
# Fold number : ------------- :  3
# Epoch 1/10
# 115/115 [==============================] - 6s 40ms/step - loss: 0.6963 - accuracy: 0.7694 - val_loss: 0.4369 - val_accuracy: 0.8603
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3403 - accuracy: 0.8998 - val_loss: 0.3559 - val_accuracy: 0.8848
# Epoch 3/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2067 - accuracy: 0.9311 - val_loss: 0.2839 - val_accuracy: 0.8848
# Epoch 4/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.1589 - accuracy: 0.9469 - val_loss: 0.2971 - val_accuracy: 0.9044
# Epoch 5/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.1257 - accuracy: 0.9578 - val_loss: 0.5440 - val_accuracy: 0.8725
# Epoch 6/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0946 - accuracy: 0.9684 - val_loss: 0.3480 - val_accuracy: 0.9020
# Epoch 7/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0748 - accuracy: 0.9766 - val_loss: 0.2557 - val_accuracy: 0.9191
# Epoch 8/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.0628 - accuracy: 0.9782 - val_loss: 0.3365 - val_accuracy: 0.9044
# Epoch 9/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.0551 - accuracy: 0.9809 - val_loss: 0.4226 - val_accuracy: 0.8848
# Epoch 10/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.0454 - accuracy: 0.9842 - val_loss: 0.2969 - val_accuracy: 0.9069
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2969 - accuracy: 0.9069
# Fold number : ------------- :  4
# Epoch 1/10
# 115/115 [==============================] - 6s 41ms/step - loss: 0.7511 - accuracy: 0.7626 - val_loss: 0.2178 - val_accuracy: 0.9265
# Epoch 2/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.6331 - accuracy: 0.8748 - val_loss: 0.1646 - val_accuracy: 0.9338
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2935 - accuracy: 0.9061 - val_loss: 0.1085 - val_accuracy: 0.9755
# Epoch 4/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2287 - accuracy: 0.9287 - val_loss: 0.0857 - val_accuracy: 0.9755
# Epoch 5/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.1675 - accuracy: 0.9396 - val_loss: 0.0762 - val_accuracy: 0.9706
# Epoch 6/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.1301 - accuracy: 0.9567 - val_loss: 0.0974 - val_accuracy: 0.9706
# Epoch 7/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.1034 - accuracy: 0.9676 - val_loss: 0.0918 - val_accuracy: 0.9681
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0892 - accuracy: 0.9706 - val_loss: 0.0942 - val_accuracy: 0.9681
# Epoch 9/10
# 115/115 [==============================] - 5s 46ms/step - loss: 0.0732 - accuracy: 0.9785 - val_loss: 0.1210 - val_accuracy: 0.9583
# Epoch 10/10
# 115/115 [==============================] - 5s 43ms/step - loss: 0.0637 - accuracy: 0.9804 - val_loss: 0.0749 - val_accuracy: 0.9755
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0749 - accuracy: 0.9755
# Fold number : ------------- :  5
# Epoch 1/10
# 115/115 [==============================] - 7s 49ms/step - loss: 3.7182 - accuracy: 0.7574 - val_loss: 0.8882 - val_accuracy: 0.7598
# Epoch 2/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.3654 - accuracy: 0.8786 - val_loss: 1.0121 - val_accuracy: 0.7500
# Epoch 3/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.3061 - accuracy: 0.9123 - val_loss: 1.1170 - val_accuracy: 0.7549
# Epoch 4/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.2038 - accuracy: 0.9314 - val_loss: 1.0693 - val_accuracy: 0.7672
# Epoch 5/10
# 115/115 [==============================] - 5s 44ms/step - loss: 0.1468 - accuracy: 0.9507 - val_loss: 1.2536 - val_accuracy: 0.7451
# Epoch 6/10
# 115/115 [==============================] - 5s 43ms/step - loss: 0.2597 - accuracy: 0.9385 - val_loss: 1.1461 - val_accuracy: 0.7353
# Epoch 7/10
# 115/115 [==============================] - 6s 51ms/step - loss: 0.1380 - accuracy: 0.9524 - val_loss: 1.3179 - val_accuracy: 0.7426
# Epoch 8/10
# 115/115 [==============================] - 6s 48ms/step - loss: 0.0961 - accuracy: 0.9714 - val_loss: 1.4844 - val_accuracy: 0.7721
# Epoch 9/10
# 115/115 [==============================] - 5s 46ms/step - loss: 0.0755 - accuracy: 0.9774 - val_loss: 1.5463 - val_accuracy: 0.7451
# Epoch 10/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.0530 - accuracy: 0.9858 - val_loss: 1.5755 - val_accuracy: 0.7672
# 13/13 [==============================] - 0s 8ms/step - loss: 1.5755 - accuracy: 0.7672
# Fold number : ------------- :  6
# Epoch 1/10
# 115/115 [==============================] - 6s 39ms/step - loss: 82.2353 - accuracy: 0.6534 - val_loss: 1.9112 - val_accuracy: 0.7108
# Epoch 2/10
# 115/115 [==============================] - 4s 37ms/step - loss: 24.1200 - accuracy: 0.7789 - val_loss: 0.9563 - val_accuracy: 0.7598
# Epoch 3/10
# 115/115 [==============================] - 4s 37ms/step - loss: 1.9201 - accuracy: 0.8301 - val_loss: 0.8476 - val_accuracy: 0.7525
# Epoch 4/10
# 115/115 [==============================] - 4s 37ms/step - loss: 14.0861 - accuracy: 0.8200 - val_loss: 1.9385 - val_accuracy: 0.6789
# Epoch 5/10
# 115/115 [==============================] - 4s 37ms/step - loss: 3.7397 - accuracy: 0.8100 - val_loss: 0.8572 - val_accuracy: 0.7745
# Epoch 6/10
# 115/115 [==============================] - 4s 37ms/step - loss: 2.1504 - accuracy: 0.8617 - val_loss: 0.8158 - val_accuracy: 0.7892
# Epoch 7/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.3542 - accuracy: 0.8892 - val_loss: 0.8504 - val_accuracy: 0.7623
# Epoch 8/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.3327 - accuracy: 0.9053 - val_loss: 0.8197 - val_accuracy: 0.8064
# Epoch 9/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2724 - accuracy: 0.9178 - val_loss: 0.8490 - val_accuracy: 0.7917
# Epoch 10/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2422 - accuracy: 0.9235 - val_loss: 0.8691 - val_accuracy: 0.7990
# 13/13 [==============================] - 0s 16ms/step - loss: 0.8691 - accuracy: 0.7990
# Fold number : ------------- :  7
# Epoch 1/10
# 115/115 [==============================] - 6s 35ms/step - loss: 0.7227 - accuracy: 0.7675 - val_loss: 0.5683 - val_accuracy: 0.9044
# Epoch 2/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.3207 - accuracy: 0.8938 - val_loss: 0.9764 - val_accuracy: 0.9240
# Epoch 3/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.2331 - accuracy: 0.9219 - val_loss: 41.6268 - val_accuracy: 0.9191
# Epoch 4/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2497 - accuracy: 0.9355 - val_loss: 1.1365 - val_accuracy: 0.9240
# Epoch 5/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1447 - accuracy: 0.9483 - val_loss: 1.6178 - val_accuracy: 0.9387
# Epoch 6/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.3053 - accuracy: 0.9575 - val_loss: 1.7467 - val_accuracy: 0.9265
# Epoch 7/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.1202 - accuracy: 0.9592 - val_loss: 1.9076 - val_accuracy: 0.9289
# Epoch 8/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0812 - accuracy: 0.9722 - val_loss: 2.0861 - val_accuracy: 0.9240
# Epoch 9/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.0549 - accuracy: 0.9828 - val_loss: 2.8660 - val_accuracy: 0.9436
# Epoch 10/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0446 - accuracy: 0.9869 - val_loss: 2.6095 - val_accuracy: 0.9265
# 13/13 [==============================] - 0s 10ms/step - loss: 2.6095 - accuracy: 0.9265
# Fold number : ------------- :  8
# Epoch 1/10
# 115/115 [==============================] - 7s 44ms/step - loss: 0.8030 - accuracy: 0.7604 - val_loss: 0.4787 - val_accuracy: 0.8162
# Epoch 2/10
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3334 - accuracy: 0.8876 - val_loss: 0.2860 - val_accuracy: 0.9142
# Epoch 3/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.2264 - accuracy: 0.9257 - val_loss: 0.2797 - val_accuracy: 0.9118
# Epoch 4/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.1807 - accuracy: 0.9393 - val_loss: 0.2737 - val_accuracy: 0.9069
# Epoch 5/10
# 115/115 [==============================] - 5s 43ms/step - loss: 0.1331 - accuracy: 0.9570 - val_loss: 0.3072 - val_accuracy: 0.9020
# Epoch 6/10
# 115/115 [==============================] - 5s 45ms/step - loss: 0.1000 - accuracy: 0.9662 - val_loss: 0.2660 - val_accuracy: 0.9167
# Epoch 7/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.0727 - accuracy: 0.9799 - val_loss: 0.2591 - val_accuracy: 0.9240
# Epoch 8/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0467 - accuracy: 0.9880 - val_loss: 0.2971 - val_accuracy: 0.9069
# Epoch 9/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0437 - accuracy: 0.9877 - val_loss: 0.2848 - val_accuracy: 0.9118
# Epoch 10/10
# 115/115 [==============================] - 5s 43ms/step - loss: 0.0363 - accuracy: 0.9902 - val_loss: 0.2873 - val_accuracy: 0.9216
# 13/13 [==============================] - 0s 10ms/step - loss: 0.2873 - accuracy: 0.9216
# Fold number : ------------- :  9
# Epoch 1/10
# 115/115 [==============================] - 6s 40ms/step - loss: 0.7375 - accuracy: 0.7645 - val_loss: 0.3832 - val_accuracy: 0.8824
# Epoch 2/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.3423 - accuracy: 0.8933 - val_loss: 0.3128 - val_accuracy: 0.9289
# Epoch 3/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2540 - accuracy: 0.9167 - val_loss: 0.2724 - val_accuracy: 0.9191
# Epoch 4/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1842 - accuracy: 0.9336 - val_loss: 0.2944 - val_accuracy: 0.9240
# Epoch 5/10
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1454 - accuracy: 0.9521 - val_loss: 0.2340 - val_accuracy: 0.9338
# Epoch 6/10
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1026 - accuracy: 0.9673 - val_loss: 0.2807 - val_accuracy: 0.9314
# Epoch 7/10
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0866 - accuracy: 0.9717 - val_loss: 0.2959 - val_accuracy: 0.9387
# Epoch 8/10
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0655 - accuracy: 0.9779 - val_loss: 0.3326 - val_accuracy: 0.9412
# Epoch 9/10
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0615 - accuracy: 0.9777 - val_loss: 0.2716 - val_accuracy: 0.9387
# Epoch 10/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0786 - accuracy: 0.9809 - val_loss: 0.3828 - val_accuracy: 0.9118
# 13/13 [==============================] - 0s 8ms/step - loss: 0.3828 - accuracy: 0.9118
# Fold number : ------------- :  10
# Epoch 1/10
# 115/115 [==============================] - 6s 38ms/step - loss: 0.7812 - accuracy: 0.7430 - val_loss: 0.7727 - val_accuracy: 0.8039
# Epoch 2/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.4195 - accuracy: 0.8821 - val_loss: 1.4050 - val_accuracy: 0.8235
# Epoch 3/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2689 - accuracy: 0.9151 - val_loss: 0.5887 - val_accuracy: 0.8480
# Epoch 4/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1834 - accuracy: 0.9393 - val_loss: 1.2074 - val_accuracy: 0.8064
# Epoch 5/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1424 - accuracy: 0.9491 - val_loss: 1.2643 - val_accuracy: 0.8235
# Epoch 6/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1079 - accuracy: 0.9630 - val_loss: 9.9739 - val_accuracy: 0.8603
# Epoch 7/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0852 - accuracy: 0.9741 - val_loss: 1.6123 - val_accuracy: 0.8480
# Epoch 8/10
# 115/115 [==============================] - 4s 36ms/step - loss: 2710.5955 - accuracy: 0.8628 - val_loss: 2.0510 - val_accuracy: 0.7966
# Epoch 9/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.2970 - accuracy: 0.9221 - val_loss: 1.6871 - val_accuracy: 0.8407
# Epoch 10/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1996 - accuracy: 0.9423 - val_loss: 1.5120 - val_accuracy: 0.8309
# 13/13 [==============================] - 0s 8ms/step - loss: 1.5120 - accuracy: 0.8309

# %%
#Per Participant Cross Validation
#Subject 1
df_sub1, df_subj_1 = sliding_window_samples(d1_s1, window_length, overlap)
data_s1 = np.array(df_sub1, dtype = float)

X_s1 = data_s1[:, : ,0:12]
y_s1 = data_s1[:, : , 12]
X_dummy, y_s1 = reshape(X_s1, y_s1)
fold_s1=4
scores_s1, f1_scores_s1, matrix_s1 = model_LSTM(X_s1,y_s1,fold_s1)
acc_scores_s1 = scores_s1[:,-1]
c_matrix_s1 = matrix_s1[-1]
# Out:
# Fold number : ------------- :  1
# Epoch 1/10
# 43/43 [==============================] - 3s 43ms/step - loss: 0.7285 - accuracy: 0.7469 - val_loss: 0.5761 - val_accuracy: 0.8070
# Epoch 2/10
# 43/43 [==============================] - 2s 38ms/step - loss: 0.2398 - accuracy: 0.9100 - val_loss: 0.4887 - val_accuracy: 0.8706
# Epoch 3/10
# 43/43 [==============================] - 2s 41ms/step - loss: 0.1248 - accuracy: 0.9510 - val_loss: 0.5238 - val_accuracy: 0.8750
# Epoch 4/10
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0583 - accuracy: 0.9817 - val_loss: 0.7327 - val_accuracy: 0.8377
# Epoch 5/10
# 43/43 [==============================] - 2s 50ms/step - loss: 0.0356 - accuracy: 0.9898 - val_loss: 0.8988 - val_accuracy: 0.8465
# Epoch 6/10
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0252 - accuracy: 0.9920 - val_loss: 0.9098 - val_accuracy: 0.8443
# Epoch 7/10
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0346 - accuracy: 0.9898 - val_loss: 0.9358 - val_accuracy: 0.8487
# Epoch 8/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0824 - accuracy: 0.9941 - val_loss: 0.8591 - val_accuracy: 0.8662
# Epoch 9/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0195 - accuracy: 0.9963 - val_loss: 0.9402 - val_accuracy: 0.8531
# Epoch 10/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0198 - accuracy: 0.9978 - val_loss: 1.1794 - val_accuracy: 0.8487
# 15/15 [==============================] - 0s 9ms/step - loss: 1.1794 - accuracy: 0.8487
# Fold number : ------------- :  2
# Epoch 1/10
# 43/43 [==============================] - 3s 42ms/step - loss: 0.6527 - accuracy: 0.7879 - val_loss: 0.5033 - val_accuracy: 0.8487
# Epoch 2/10
# 43/43 [==============================] - 2s 36ms/step - loss: 0.2328 - accuracy: 0.9181 - val_loss: 0.3738 - val_accuracy: 0.8816
# Epoch 3/10
# 43/43 [==============================] - 2s 40ms/step - loss: 0.1489 - accuracy: 0.9532 - val_loss: 0.5561 - val_accuracy: 0.8794
# Epoch 4/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.1024 - accuracy: 0.9634 - val_loss: 0.4018 - val_accuracy: 0.9013
# Epoch 5/10
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0696 - accuracy: 0.9788 - val_loss: 0.3874 - val_accuracy: 0.9035
# Epoch 6/10
# 43/43 [==============================] - 2s 38ms/step - loss: 0.0611 - accuracy: 0.9781 - val_loss: 0.3995 - val_accuracy: 0.9123
# Epoch 7/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0547 - accuracy: 0.9846 - val_loss: 0.5163 - val_accuracy: 0.8860
# Epoch 8/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0664 - accuracy: 0.9846 - val_loss: 0.3819 - val_accuracy: 0.8991
# Epoch 9/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0381 - accuracy: 0.9912 - val_loss: 0.4497 - val_accuracy: 0.8838
# Epoch 10/10
# 43/43 [==============================] - 2s 38ms/step - loss: 0.0207 - accuracy: 0.9971 - val_loss: 0.3649 - val_accuracy: 0.9079
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3649 - accuracy: 0.9079
# Fold number : ------------- :  3
# Epoch 1/10
# 43/43 [==============================] - 3s 47ms/step - loss: 0.8396 - accuracy: 0.6884 - val_loss: 0.1771 - val_accuracy: 0.9627
# Epoch 2/10
# 43/43 [==============================] - 2s 37ms/step - loss: 0.3160 - accuracy: 0.8866 - val_loss: 0.0860 - val_accuracy: 0.9803
# Epoch 3/10
# 43/43 [==============================] - 2s 40ms/step - loss: 0.1827 - accuracy: 0.9312 - val_loss: 0.0551 - val_accuracy: 0.9868
# Epoch 4/10
# 43/43 [==============================] - 2s 41ms/step - loss: 0.1350 - accuracy: 0.9503 - val_loss: 0.0497 - val_accuracy: 0.9846
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0782 - accuracy: 0.9751 - val_loss: 0.0439 - val_accuracy: 0.9890
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0650 - accuracy: 0.9802 - val_loss: 0.0509 - val_accuracy: 0.9868
# Epoch 7/10
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0447 - accuracy: 0.9839 - val_loss: 0.0462 - val_accuracy: 0.9890
# Epoch 8/10
# 43/43 [==============================] - 2s 39ms/step - loss: 1.9962 - accuracy: 0.9839 - val_loss: 0.0700 - val_accuracy: 0.9825
# Epoch 9/10
# 43/43 [==============================] - 2s 38ms/step - loss: 167.5548 - accuracy: 0.9203 - val_loss: 0.6705 - val_accuracy: 0.9583
# Epoch 10/10
# 43/43 [==============================] - 2s 37ms/step - loss: 1.3331 - accuracy: 0.9342 - val_loss: 0.0488 - val_accuracy: 0.9912
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0488 - accuracy: 0.9912
# Fold number : ------------- :  4
# Epoch 1/10
# 43/43 [==============================] - 3s 40ms/step - loss: 0.5881 - accuracy: 0.8070 - val_loss: 0.8701 - val_accuracy: 0.7956
# Epoch 2/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1763 - accuracy: 0.9357 - val_loss: 0.9216 - val_accuracy: 0.7912
# Epoch 3/10
# 43/43 [==============================] - 1s 35ms/step - loss: 0.1130 - accuracy: 0.9583 - val_loss: 0.9815 - val_accuracy: 0.8066
# Epoch 4/10
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0701 - accuracy: 0.9759 - val_loss: 1.5998 - val_accuracy: 0.7736
# Epoch 5/10
# 43/43 [==============================] - 2s 37ms/step - loss: 0.0537 - accuracy: 0.9788 - val_loss: 1.1551 - val_accuracy: 0.8000
# Epoch 6/10
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0366 - accuracy: 0.9883 - val_loss: 1.8548 - val_accuracy: 0.7802
# Epoch 7/10
# 43/43 [==============================] - 2s 37ms/step - loss: 0.1384 - accuracy: 0.9832 - val_loss: 8.6732 - val_accuracy: 0.7692
# Epoch 8/10
# 43/43 [==============================] - 1s 35ms/step - loss: 0.5994 - accuracy: 0.9576 - val_loss: 1.2302 - val_accuracy: 0.8066
# Epoch 9/10
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0367 - accuracy: 0.9876 - val_loss: 1.5327 - val_accuracy: 0.8132
# Epoch 10/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.0312 - accuracy: 0.9927 - val_loss: 1.5655 - val_accuracy: 0.8154
# 15/15 [==============================] - 0s 7ms/step - loss: 1.5655 - accuracy: 0.8154

# %%
#Subject 2
df_sub2, df_subj_2 = sliding_window_samples(d2_s2, window_length, overlap)
data_s2 = np.array(df_sub2, dtype = float)

X_s2 = data_s2[:, : ,0:12]
y_s2 = data_s2[:, : , 12]
X_dummy, y_s2 = reshape(X_s2, y_s2)
fold_s2=8
scores_s2, f1_scores_s2, matrix_s2  = model_LSTM(X_s2,y_s2,fold_s2)
acc_scores_s2 = scores_s2[:,-1]
c_matrix_s2 = matrix_s2[-1]
# Out:
# Fold number : ------------- :  1
# Epoch 1/10
# 62/62 [==============================] - 3s 34ms/step - loss: 0.7723 - accuracy: 0.7462 - val_loss: 1.0068 - val_accuracy: 0.7314
# Epoch 2/10
# 62/62 [==============================] - 2s 32ms/step - loss: 0.2404 - accuracy: 0.9260 - val_loss: 1.0734 - val_accuracy: 0.7633
# Epoch 3/10
# 62/62 [==============================] - 2s 31ms/step - loss: 0.3661 - accuracy: 0.9438 - val_loss: 1.3280 - val_accuracy: 0.7633
# Epoch 4/10
# 62/62 [==============================] - 2s 33ms/step - loss: 0.2525 - accuracy: 0.9397 - val_loss: 1.1224 - val_accuracy: 0.7279
# Epoch 5/10
# 62/62 [==============================] - 2s 35ms/step - loss: 0.1032 - accuracy: 0.9681 - val_loss: 1.1303 - val_accuracy: 0.7774
# Epoch 6/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0752 - accuracy: 0.9787 - val_loss: 1.1761 - val_accuracy: 0.7703
# Epoch 7/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0440 - accuracy: 0.9868 - val_loss: 1.3005 - val_accuracy: 0.7633
# Epoch 8/10
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0316 - accuracy: 0.9939 - val_loss: 1.3350 - val_accuracy: 0.7739
# Epoch 9/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0197 - accuracy: 0.9965 - val_loss: 1.3948 - val_accuracy: 0.7668
# Epoch 10/10
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0159 - accuracy: 0.9970 - val_loss: 1.3678 - val_accuracy: 0.7668
# 9/9 [==============================] - 0s 8ms/step - loss: 1.3678 - accuracy: 0.7668
# Fold number : ------------- :  2
# Epoch 1/10
# 62/62 [==============================] - 4s 41ms/step - loss: 1.0699 - accuracy: 0.6648 - val_loss: 0.8534 - val_accuracy: 0.8085
# Epoch 2/10
# 62/62 [==============================] - 3s 41ms/step - loss: 0.3915 - accuracy: 0.8790 - val_loss: 0.8376 - val_accuracy: 0.8369
# Epoch 3/10
# 62/62 [==============================] - 2s 38ms/step - loss: 0.2540 - accuracy: 0.9205 - val_loss: 0.9594 - val_accuracy: 0.8830
# Epoch 4/10
# 62/62 [==============================] - 3s 43ms/step - loss: 0.1789 - accuracy: 0.9468 - val_loss: 2.2001 - val_accuracy: 0.8901
# Epoch 5/10
# 62/62 [==============================] - 3s 43ms/step - loss: 0.1136 - accuracy: 0.9646 - val_loss: 3.6485 - val_accuracy: 0.8830
# Epoch 6/10
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0848 - accuracy: 0.9757 - val_loss: 6.3512 - val_accuracy: 0.8865
# Epoch 7/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0659 - accuracy: 0.9853 - val_loss: 18.4106 - val_accuracy: 0.8830
# Epoch 8/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0468 - accuracy: 0.9878 - val_loss: 27.6526 - val_accuracy: 0.8865
# Epoch 9/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1047 - accuracy: 0.9838 - val_loss: 15.7553 - val_accuracy: 0.8404
# Epoch 10/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1101 - accuracy: 0.9676 - val_loss: 12.2740 - val_accuracy: 0.9113
# 9/9 [==============================] - 0s 8ms/step - loss: 12.2740 - accuracy: 0.9113
# Fold number : ------------- :  3
# Epoch 1/10
# 62/62 [==============================] - 4s 40ms/step - loss: 0.9090 - accuracy: 0.6684 - val_loss: 0.4947 - val_accuracy: 0.8262
# Epoch 2/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.5019 - accuracy: 0.8739 - val_loss: 0.3580 - val_accuracy: 0.8794
# Epoch 3/10
# 62/62 [==============================] - 2s 37ms/step - loss: 178.3000 - accuracy: 0.8972 - val_loss: 0.2738 - val_accuracy: 0.9078
# Epoch 4/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.2443 - accuracy: 0.9281 - val_loss: 0.2541 - val_accuracy: 0.9078
# Epoch 5/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1703 - accuracy: 0.9448 - val_loss: 0.2746 - val_accuracy: 0.8972
# Epoch 6/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1446 - accuracy: 0.9595 - val_loss: 0.3024 - val_accuracy: 0.9007
# Epoch 7/10
# 62/62 [==============================] - 3s 42ms/step - loss: 0.1137 - accuracy: 0.9656 - val_loss: 0.2476 - val_accuracy: 0.9113
# Epoch 8/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0793 - accuracy: 0.9777 - val_loss: 0.2405 - val_accuracy: 0.9149
# Epoch 9/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0667 - accuracy: 0.9838 - val_loss: 0.2581 - val_accuracy: 0.9149
# Epoch 10/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0559 - accuracy: 0.9868 - val_loss: 0.2691 - val_accuracy: 0.9043
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2691 - accuracy: 0.9043
# Fold number : ------------- :  4
# Epoch 1/10
# 62/62 [==============================] - 4s 41ms/step - loss: 0.8834 - accuracy: 0.7018 - val_loss: 0.7141 - val_accuracy: 0.7553
# Epoch 2/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.2925 - accuracy: 0.9084 - val_loss: 0.6994 - val_accuracy: 0.7908
# Epoch 3/10
# 62/62 [==============================] - 2s 39ms/step - loss: 0.2058 - accuracy: 0.9271 - val_loss: 0.6228 - val_accuracy: 0.8369
# Epoch 4/10
# 62/62 [==============================] - 3s 42ms/step - loss: 0.1365 - accuracy: 0.9549 - val_loss: 0.6217 - val_accuracy: 0.8369
# Epoch 5/10
# 62/62 [==============================] - 3s 45ms/step - loss: 0.0777 - accuracy: 0.9782 - val_loss: 0.6716 - val_accuracy: 0.8475
# Epoch 6/10
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0447 - accuracy: 0.9884 - val_loss: 0.6588 - val_accuracy: 0.8652
# Epoch 7/10
# 62/62 [==============================] - 2s 33ms/step - loss: 2.2821 - accuracy: 0.9792 - val_loss: 0.9126 - val_accuracy: 0.8121
# Epoch 8/10
# 62/62 [==============================] - 2s 35ms/step - loss: 0.2323 - accuracy: 0.9266 - val_loss: 0.7324 - val_accuracy: 0.8546
# Epoch 9/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0648 - accuracy: 0.9772 - val_loss: 0.7097 - val_accuracy: 0.8511
# Epoch 10/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0507 - accuracy: 0.9884 - val_loss: 0.7469 - val_accuracy: 0.8546
# 9/9 [==============================] - 0s 9ms/step - loss: 0.7469 - accuracy: 0.8546
# Fold number : ------------- :  5
# Epoch 1/10
# 62/62 [==============================] - 4s 40ms/step - loss: 1.4229 - accuracy: 0.6633 - val_loss: 0.3775 - val_accuracy: 0.9007
# Epoch 2/10
# 62/62 [==============================] - 2s 35ms/step - loss: 0.4187 - accuracy: 0.8714 - val_loss: 0.2530 - val_accuracy: 0.9291
# Epoch 3/10
# 62/62 [==============================] - 2s 35ms/step - loss: 0.2634 - accuracy: 0.9124 - val_loss: 0.2149 - val_accuracy: 0.9220
# Epoch 4/10
# 62/62 [==============================] - 2s 34ms/step - loss: 0.1797 - accuracy: 0.9403 - val_loss: 0.2162 - val_accuracy: 0.9255
# Epoch 5/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1463 - accuracy: 0.9499 - val_loss: 0.2392 - val_accuracy: 0.9184
# Epoch 6/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1095 - accuracy: 0.9666 - val_loss: 0.2082 - val_accuracy: 0.9291
# Epoch 7/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0488 - accuracy: 0.9868 - val_loss: 0.2343 - val_accuracy: 0.9291
# Epoch 8/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0514 - accuracy: 0.9843 - val_loss: 0.2131 - val_accuracy: 0.9291
# Epoch 9/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0329 - accuracy: 0.9924 - val_loss: 0.2196 - val_accuracy: 0.9291
# Epoch 10/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0314 - accuracy: 0.9919 - val_loss: 0.2279 - val_accuracy: 0.9255
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2279 - accuracy: 0.9255
# Fold number : ------------- :  6
# Epoch 1/10
# 62/62 [==============================] - 4s 40ms/step - loss: 0.8772 - accuracy: 0.6962 - val_loss: 0.5015 - val_accuracy: 0.8723
# Epoch 2/10
# 62/62 [==============================] - 2s 35ms/step - loss: 0.3506 - accuracy: 0.8861 - val_loss: 0.3616 - val_accuracy: 0.9007
# Epoch 3/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.2063 - accuracy: 0.9342 - val_loss: 0.4885 - val_accuracy: 0.9255
# Epoch 4/10
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1622 - accuracy: 0.9433 - val_loss: 0.4099 - val_accuracy: 0.9184
# Epoch 5/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1120 - accuracy: 0.9615 - val_loss: 0.4515 - val_accuracy: 0.9362
# Epoch 6/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0709 - accuracy: 0.9787 - val_loss: 0.4453 - val_accuracy: 0.9397
# Epoch 7/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0478 - accuracy: 0.9889 - val_loss: 0.5007 - val_accuracy: 0.9326
# Epoch 8/10
# 62/62 [==============================] - 2s 35ms/step - loss: 0.7028 - accuracy: 0.9494 - val_loss: 0.5305 - val_accuracy: 0.9007
# Epoch 9/10
# 62/62 [==============================] - 2s 33ms/step - loss: 0.2762 - accuracy: 0.9473 - val_loss: 0.2879 - val_accuracy: 0.9362
# Epoch 10/10
# 62/62 [==============================] - 2s 32ms/step - loss: 0.0614 - accuracy: 0.9813 - val_loss: 0.2851 - val_accuracy: 0.9326
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2851 - accuracy: 0.9326
# Fold number : ------------- :  7
# Epoch 1/10
# 62/62 [==============================] - 4s 36ms/step - loss: 1.3261 - accuracy: 0.6704 - val_loss: 0.4204 - val_accuracy: 0.8901
# Epoch 2/10
# 62/62 [==============================] - 2s 32ms/step - loss: 0.4456 - accuracy: 0.8633 - val_loss: 0.2166 - val_accuracy: 0.9397
# Epoch 3/10
# 62/62 [==============================] - 2s 33ms/step - loss: 0.2872 - accuracy: 0.9089 - val_loss: 0.1890 - val_accuracy: 0.9362
# Epoch 4/10
# 62/62 [==============================] - 2s 32ms/step - loss: 0.5415 - accuracy: 0.9327 - val_loss: 0.0972 - val_accuracy: 0.9645
# Epoch 5/10
# 62/62 [==============================] - 2s 35ms/step - loss: 0.1636 - accuracy: 0.9428 - val_loss: 0.1163 - val_accuracy: 0.9610
# Epoch 6/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1232 - accuracy: 0.9585 - val_loss: 0.1411 - val_accuracy: 0.9433
# Epoch 7/10
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0934 - accuracy: 0.9686 - val_loss: 0.0890 - val_accuracy: 0.9574
# Epoch 8/10
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0648 - accuracy: 0.9808 - val_loss: 0.1163 - val_accuracy: 0.9433
# Epoch 9/10
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0598 - accuracy: 0.9848 - val_loss: 0.1021 - val_accuracy: 0.9610
# Epoch 10/10
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0532 - accuracy: 0.9848 - val_loss: 0.0839 - val_accuracy: 0.9681
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0839 - accuracy: 0.9681
# Fold number : ------------- :  8
# Epoch 1/10
# 62/62 [==============================] - 5s 53ms/step - loss: 0.9672 - accuracy: 0.6901 - val_loss: 1.0432 - val_accuracy: 0.7057
# Epoch 2/10
# 62/62 [==============================] - 3s 47ms/step - loss: 0.3815 - accuracy: 0.8805 - val_loss: 1.3901 - val_accuracy: 0.7340
# Epoch 3/10
# 62/62 [==============================] - 3s 52ms/step - loss: 0.2180 - accuracy: 0.9256 - val_loss: 1.2471 - val_accuracy: 0.7447
# Epoch 4/10
# 62/62 [==============================] - 3s 41ms/step - loss: 0.1468 - accuracy: 0.9494 - val_loss: 1.2756 - val_accuracy: 0.7518
# Epoch 5/10
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1176 - accuracy: 0.9671 - val_loss: 1.5691 - val_accuracy: 0.7660
# Epoch 6/10
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0751 - accuracy: 0.9787 - val_loss: 1.5156 - val_accuracy: 0.7908
# Epoch 7/10
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0620 - accuracy: 0.9823 - val_loss: 1.9515 - val_accuracy: 0.7305
# Epoch 8/10
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0796 - accuracy: 0.9803 - val_loss: 2.1319 - val_accuracy: 0.7837
# Epoch 9/10
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0476 - accuracy: 0.9858 - val_loss: 1.9619 - val_accuracy: 0.7979
# Epoch 10/10
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0273 - accuracy: 0.9929 - val_loss: 1.8973 - val_accuracy: 0.7872
# 9/9 [==============================] - 0s 9ms/step - loss: 1.8973 - accuracy: 0.7872

# %%
print('Normal Cross Validation, Model : KNN')
print('Mean_accuracy: %.3f' % accuracy_n)
print('Mean_precision_score: %.3f' % precision_n)
print('Mean_recall_score: %.3f' % recall_n)
print('Mean_F1_score: %.3f' % f1_n)

print('\nSUB 1 Cross Validation, Model : KNN')
print('Mean_accuracy_s1: %.3f' % accuracy_s1)
print('Mean_precision_score_s1: %.3f' % precision_s1)
print('Mean_recall_score_s1: %.3f' % recall_s1)
print('Mean_F1_score_s1: %.3f' % f1_s1)

print('\nSUB 2 Cross Validation, Model : KNN')
print('Mean_accuracy_s2: %.3f' % accuracy_s2)
print('Mean_precision_score_s2: %.3f' % precision_s2)
print('Mean_recall_score_s2: %.3f' % recall_s2)
print('Mean_F1_score_s2: %.3f' % f1_s2)

print('\nNormal Cross Validation, Model : LSTM')
print('Accuracy : %0.4f' %acc_scores_n.mean())
print('F1_score : %0.4f' %f1_scores_n.mean())
print('Confusion_matrix : Null, dribbling, layup, running, shooting, walking\n', c_matrix_n)

print('\nSUB 1 Cross Validation, Model : LSTM')
print('Accuracy : %0.4f' %acc_scores_s1.mean())
print('F1_score : %0.4f' %f1_scores_s1.mean())
print('Confusion_matrix : Null, layup, running, shooting, walking \n', c_matrix_s1)

print('\nSUB 2 Cross Validation, Model : LSTM')
print('Accuracy : %0.4f' %acc_scores_s2.mean())
print('F1_score : %0.4f' %f1_scores_s2.mean())
print('Confusion_matrix : Null, dribbling, layup, running, shooting, walking \n', c_matrix_s2)
# Out:
# Normal Cross Validation, Model : KNN
# Mean_accuracy: 0.726
# Mean_precision_score: 0.787
# Mean_recall_score: 0.726
# Mean_F1_score: 0.703
#
# SUB 1 Cross Validation, Model : KNN
# Mean_accuracy_s1: 0.753
# Mean_precision_score_s1: 0.811
# Mean_recall_score_s1: 0.753
# Mean_F1_score_s1: 0.738
#
# SUB 2 Cross Validation, Model : KNN
# Mean_accuracy_s2: 0.754
# Mean_precision_score_s2: 0.798
# Mean_recall_score_s2: 0.754
# Mean_F1_score_s2: 0.715
#
# Normal Cross Validation, Model : LSTM
# Accuracy : 0.8802
# F1_score : 0.8792
# Confusion_matrix : Null, dribbling, layup, running, shooting, walking
#  [[84  1  0  2  0  1]
#  [ 7 30  9  0  0  0]
#  [ 0  2 68  2  0  2]
#  [ 9  0  3 49  0  0]
#  [ 2  1 11  0 42  8]
#  [ 0  0  5  3  1 66]]
#
# SUB 1 Cross Validation, Model : LSTM
# Accuracy : 0.8908
# F1_score : 0.8890
# Confusion_matrix : Null, layup, running, shooting, walking
#  [[95  8  1  6  5]
#  [ 4 78  2  0  0]
#  [ 4 18 46  0  6]
#  [ 6  5  0 73  5]
#  [ 1  2 11  0 79]]
#
# SUB 2 Cross Validation, Model : LSTM
# Accuracy : 0.8813
# F1_score : 0.8805
# Confusion_matrix : Null, dribbling, layup, running, shooting, walking
#  [[49  0  0  2  0  1]
#  [ 5 43  8  0  0  0]
#  [ 0  5 42  1  2  0]
#  [ 7  0  0 29  2  2]
#  [ 1  0  1  0 19 15]
#  [ 0  0  6  1  1 40]]
