# %% [markdown]
# ### NISHANTH IRUTHAYARAJ
# Matric. No: 1522044

# %% [markdown]
# **Data Preprocessing**

# %%
import pandas as pd
import numpy as np

#Reading files and Correcting Timestamp#
c_heads = ['Time', 'Device', 'e1' , 'e2' , 'e3' , 'e4' , 'e5' , 'e6' ,'Label']
df_sub1_esense = pd.read_csv('eSense_sbj1.csv', names = c_heads)
df_sub1_esense['Time'] = pd.to_datetime(df_sub1_esense['Time'], unit = 'ms') + pd.Timedelta('02:00:00')
df_sub1_esense = df_sub1_esense.set_index('Time').resample('10L', offset = 4000000).first().interpolate()
df_sub1_esense = df_sub1_esense.sort_index()

df_sub2_esense = pd.read_csv('eSense_sbj2.csv', names = c_heads)
df_sub2_esense['Time'] = pd.to_datetime(df_sub2_esense['Time'], unit = 'ms') + pd.Timedelta('02:00:00')
df_sub2_esense = df_sub2_esense.set_index('Time').resample('10L', offset = 4000000).first().interpolate()
df_sub2_esense = df_sub2_esense.sort_index()

# %%
#Data Interpolating and Upsampling
#Subject 1 ankle
df_layup1_ankle = pd.read_csv('layup_sbj1_ankle.csv', index_col = 0, comment= ';')
df_layup1_ankle.index = pd.date_range(start = '2021-04-14 18:22:13.554', periods = df_layup1_ankle.shape[0], freq = "10.869565L")
df_layup1_ankle = df_layup1_ankle.resample('10L', offset = 4000000).first().interpolate()

df_movements1_ankle_1 = pd.read_csv('movements_sbj1_ankle_1.csv', index_col = 0, comment= ';')
df_movements1_ankle_1.index = pd.date_range(start = '2021-04-14 18:42:32.024', periods = df_movements1_ankle_1.shape[0], freq = "10.869565L")
df_movements1_ankle_1 = df_movements1_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_shooting1_ankle_1 = pd.read_csv('shooting_sbj1_ankle.csv', index_col = 0, comment= ';')
df_shooting1_ankle_1.index = pd.date_range(start = '2021-04-14 18:12:54.024', periods = df_shooting1_ankle_1.shape[0], freq = "10.869565L")
df_shooting1_ankle_1 = df_shooting1_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_sub1_ankle = pd.concat([df_layup1_ankle,df_movements1_ankle_1,df_shooting1_ankle_1])
df_sub1_ankle = df_sub1_ankle.set_axis(['a1', 'a2', 'a3'], axis = 'columns')
#df_sub1_ankle = df_sub1_ankle.sort_index()

#Subject 2 ankle
df_dribbling2_ankle = pd.read_csv('dribbling_sbj2_ankle.csv', index_col = 0, comment= ';')
df_dribbling2_ankle.index = pd.date_range(start = '2021-04-14 19:26:42.914', periods = df_dribbling2_ankle.shape[0], freq = "10.869565L")
df_dribbling2_ankle = df_dribbling2_ankle.resample('10L', offset = 4000000).first().interpolate()

df_layup2_ankle = pd.read_csv('layup_sbj2_ankle.csv', index_col = 0, comment= ';')
df_layup2_ankle.index = pd.date_range(start = '2021-04-14 19:16:25.794', periods = df_layup2_ankle.shape[0], freq = "10.869565L")
df_layup2_ankle = df_layup2_ankle.resample('10L', offset = 4000000).first().interpolate()

df_movements2_ankle_1 = pd.read_csv('movements_sbj2_ankle_1.csv', index_col = 0, comment= ';') 
df_movements2_ankle_1.index = pd.date_range(start = '2021-04-14 19:36:19.244', periods = df_movements2_ankle_1.shape[0], freq = "10.869565L")
df_movements2_ankle_1 = df_movements2_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_shooting2_ankle_1 = pd.read_csv('shooting_sbj2_ankle_1.csv', index_col = 0, comment= ';')
df_shooting2_ankle_1.index = pd.date_range(start = '2021-04-14 18:55:50.364', periods = df_shooting2_ankle_1.shape[0], freq = "10.869565L")
df_shooting2_ankle_1 = df_shooting2_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_sub2_ankle = pd.concat([df_dribbling2_ankle, df_layup2_ankle, df_movements2_ankle_1, df_shooting2_ankle_1])
df_sub2_ankle = df_sub2_ankle.set_axis(['a1','a2','a3'], axis = 'columns')
#df_sub2_ankle = df_sub2_ankle.sort_index()

# %%
#Subject 1 wrist
df_layup1_wrist = pd.read_csv('layup_sbj1_wrist.csv', index_col = 0, comment= ';')
df_layup1_wrist.index = pd.date_range(start = '2021-04-14 18:22:52.524', periods = df_layup1_wrist.shape[0], freq = "10.869565L")
df_layup1_wrist = df_layup1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_movements1_wrist = pd.read_csv('movements_sbj1_wrist.csv', index_col = 0, comment= ';')
df_movements1_wrist.index = pd.date_range(start = '2021-04-14 18:42:05.244', periods = df_movements1_wrist.shape[0], freq = "10.869565L")
df_movements1_wrist = df_movements1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_shooting1_wrist = pd.read_csv('shooting_sbj1_wrist.csv', index_col = 0, comment= ';')
df_shooting1_wrist.index = pd.date_range(start = '2021-04-14 18:13:12.834', periods = df_shooting1_wrist.shape[0], freq = "10.869565L")
df_shooting1_wrist = df_shooting1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_sub1_wrist = pd.concat([df_layup1_wrist, df_movements1_wrist, df_shooting1_wrist])
df_sub1_wrist = df_sub1_wrist.set_axis(['w1','w2','w3'], axis = 'columns')
#df_sub1_wrist = df_sub1_wrist.sort_index()

#Subject 2 wrist
df_dribbling2_wrist = pd.read_csv('dribbling_sbj2_wrist.csv', index_col = 0, comment= ';')
df_dribbling2_wrist.index = pd.date_range(start = '2021-04-14 19:26:24.464', periods = df_dribbling2_wrist.shape[0], freq = "10.869565L")
df_dribbling2_wrist = df_dribbling2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_layup2_wrist = pd.read_csv('layup_sbj2_wrist.csv', index_col = 0, comment= ';')
df_layup2_wrist.index = pd.date_range(start = '2021-04-14 19:16:05.604', periods = df_layup2_wrist.shape[0], freq = "10.869565L")
df_layup2_wrist = df_layup2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_movements2_wrist = pd.read_csv('movements_sbj2_wrist.csv', index_col = 0, comment= ';') 
df_movements2_wrist.index = pd.date_range(start = '2021-04-14 19:36:45.074', periods = df_movements2_wrist.shape[0], freq = "10.869565L")
df_movements2_wrist = df_movements2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_shooting2_wrist = pd.read_csv('shooting_sbj2_wrist.csv', index_col = 0, comment= ';')
df_shooting2_wrist.index = pd.date_range(start = '2021-04-14 18:56:21.474', periods = df_shooting2_wrist.shape[0], freq = "10.869565L")
df_shooting2_wrist = df_shooting2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_sub2_wrist = pd.concat([df_dribbling2_wrist, df_layup2_wrist, df_movements2_wrist, df_shooting2_wrist])
df_sub2_wrist = df_sub2_wrist.set_axis(['w1','w2','w3'], axis = 'columns')
#df_sub2_wrist = df_sub2_wrist.sort_index()

# %%
#Merging and Normalising
df_sub1 = df_sub1_esense.merge(df_sub1_ankle, left_index=True, right_index=True)
df_1 = df_sub1.merge(df_sub1_wrist, left_index=True, right_index=True)
df_1 = (df_1 - df_1.mean()) / df_1.std()
df_1 = df_1.drop(['Device'], axis = 1)

df_sub2 = df_sub2_esense.merge(df_sub2_ankle, left_index=True, right_index=True)
df_2 = df_sub2.merge(df_sub2_wrist, left_index=True, right_index=True)
df_2 = (df_2 - df_2.mean()) / df_2.std()
df_2 = df_2.drop(['Device'], axis = 1)

# %%
#Finding Samples for Time Intersection
intersection_1 = [df_1.index.isin(df_1.between_time('18:23:14', '18:25:28').index),
                  df_1.index.isin(df_1.between_time('18:45:17', '18:47:16').index),
                  df_1.index.isin(df_1.between_time('18:13:25', '18:15:47').index),
                  df_1.index.isin(df_1.between_time('18:42:48', '18:45:17').index)]
activity_1 = ['layup', 'running', 'shooting', 'walking']
df_1['Label'] = np.select(intersection_1, activity_1, 'Null')
df_1['Subjects'] = 'Subject1'
df_1 = df_1[['e1','e2','e3','e4','e5','e6','a1','a2','a3','w1','w2','w3','Label','Subjects']]

intersection_2 = [df_2.index.isin(df_2.between_time('19:26:58', '19:29:59').index), 
                df_2.index.isin(df_2.between_time('19:17:35', '19:20:14').index),
                df_2.index.isin(df_2.between_time('19:39:47', '19:41:55').index),
                df_2.index.isin(df_2.between_time('19:00:14', '19:02:12').index),
                df_2.index.isin(df_2.between_time('19:37:15', '19:39:46').index)]
activity_2 = ['dribbling', 'layup', 'running', 'shooting', 'walking']
df_2['Label'] = np.select(intersection_2, activity_2, 'Null')
df_2['Subjects'] = 'Subject2'
df_2 = df_2[['e1','e2','e3','e4','e5','e6','a1','a2','a3','w1','w2','w3','Label','Subjects']]

df = pd.concat([df_1, df_2])
df.reset_index(drop=True, inplace=True)
df.to_csv('df_activity.csv')

# %%
#Importing and Label Encoding 
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('df_activity.csv', index_col = 0)
label = LabelEncoder()
df['Label'] = label.fit_transform(df['Label'].values)

df_new = df.drop(['Subjects'], axis = 1)

df_s1 = df.loc[df['Subjects'] == 'Subject1']
d1_s1 = df_s1.drop(['Subjects'], axis = 1)

df_s2 = df.loc[df['Subjects'] == 'Subject2']
d2_s2 = df_s2.drop(['Subjects'], axis = 1)

window_length = 100
overlap = 60

# %%
#Sliding Window
def sliding_window_samples(data, samples_per_window, overlap_ratio):
    """
    Return a sliding window measured in number of samples over a data array.

    :param data: input array, can be numpy or pandas dataframe
    :param samples_per_window: window length as number of samples per window
    :param overlap_ratio: overlap is meant as percentage and should be an integer value
    :return: tuple of windows and indices
    """
    windows = []
    indices = []
    curr = 0
    win_len = samples_per_window
    if overlap_ratio is not None:
        overlapping_elements = int((overlap_ratio / 100) * (win_len))
        if overlapping_elements >= win_len:
            print('Number of overlapping elements exceeds window size.')
            return
    while curr < len(data) - win_len:
        windows.append(data[curr:curr + win_len])
        indices.append([curr, curr + win_len])
        curr = curr + win_len - overlapping_elements
    try:
        result_windows = np.array(windows)
        result_indices = np.array(indices)
    except:
        result_windows = np.empty(shape=(len(windows), win_len, data.shape[1]), dtype=object)
        result_indices = np.array(indices)
        for i in range(0, len(windows)):
            result_windows[i] = windows[i]
            result_indices[i] = indices[i]

    return result_windows, result_indices

# %%
#Dimension Reduction for Model
def dim_reduction(x,s):
    axis = 1
    x_new = np.reshape(x, (x.shape[0], -1))
    y, indices = np.unique(s, return_inverse=True)
    y_new = y[np.argmax(np.apply_along_axis(np.bincount, axis, indices.reshape(s.shape),None, np.max(indices) + 1), axis=axis)]
    return x_new, y_new

# %% [markdown]
# **KNN Model**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold, cross_val_score

def model(features, target, score):
    knn = KNeighborsClassifier(n_neighbors = 3,  p = 2)
    kfold = KFold(n_splits = 10, random_state=42, shuffle=True)
    scores = cross_val_score(knn, features, target, cv = kfold, scoring = score, n_jobs = -1)
    return scores.mean()

# %%
#Normal Cross Validation for KNN
df_1, df_2 = sliding_window_samples(df_new, window_length, overlap)
data = np.array(df_1, dtype = float)

X_data = data[:, : ,0:12]
y_data = data[:, : , 12]
X_n, y_n = dim_reduction(X_data, y_data)

print('Normal Cross Validation with 10 folds, Model : KNN')
print('Mean_accuracy: %.3f' % model(X_n, y_n, 'accuracy'))
print('Mean_precision_score: %.3f' % model(X_n, y_n, 'precision_weighted'))
print('Mean_recall_score: %.3f' % model(X_n, y_n, 'recall_weighted'))
print('Mean_F1_score: %.3f' % model(X_n, y_n, 'f1_weighted'))
# Out:
# Normal Cross Validation with 10 folds, Model : KNN
# Mean_accuracy: 0.726
# Mean_precision_score: 0.787
# Mean_recall_score: 0.726
# Mean_F1_score: 0.703

# %%
#Per Participant Cross Validation for KNN
#Subject 1
df_sub1, df_subj_1 = sliding_window_samples(d1_s1, window_length, overlap)
data_s1 = np.array(df_sub1, dtype = float)

X_s1 = data_s1[:, : ,0:12]
y_s1 = data_s1[:, : , 12]
X_sub1, y_sub1 = dim_reduction(X_s1, y_s1)

print('SUB 1 Cross Validation with 10 folds, Model : KNN')
print('Mean_accuracy_s1: %.3f' % model(X_sub1, y_sub1, 'accuracy'))
print('Mean_precision_score_s1: %.3f' % model(X_sub1, y_sub1, 'precision_weighted'))
print('Mean_recall_score_s1: %.3f' % model(X_sub1, y_sub1, 'recall_weighted'))
print('Mean_F1_score_s1: %.3f' % model(X_sub1, y_sub1, 'f1_weighted'))
# Out:
# SUB 1 Cross Validation with 10 folds, Model : KNN
# Mean_accuracy_s1: 0.753
# Mean_precision_score_s1: 0.811
# Mean_recall_score_s1: 0.753
# Mean_F1_score_s1: 0.738

# %%
#Subject 2
df_sub2, df_subj_2 = sliding_window_samples(d2_s2, window_length, overlap)
data_s2 = np.array(df_sub2, dtype = float)

X_s2 = data_s2[:, : ,0:12]
y_s2 = data_s2[:, : , 12]
X_sub2, y_sub2 = dim_reduction(X_s2, y_s2)

print('SUB 2 Cross Validation with 10 folds, Model : KNN')
print('Mean_accuracy_s2: %.3f' % model(X_sub2, y_sub2, 'accuracy'))
print('Mean_precision_score_s2: %.3f' % model(X_sub2, y_sub2, 'precision_weighted'))
print('Mean_recall_score_s2: %.3f' % model(X_sub2, y_sub2, 'recall_weighted'))
print('Mean_F1_score_s2: %.3f' % model(X_sub2, y_sub2, 'f1_weighted'))
# Out:
# SUB 2 Cross Validation with 10 folds, Model : KNN
# Mean_accuracy_s2: 0.754
# Mean_precision_score_s2: 0.798
# Mean_recall_score_s2: 0.754
# Mean_F1_score_s2: 0.715

# %% [markdown]
# **LSTM model**

# %%
df_1, df_2 = sliding_window_samples(df_new, window_length, overlap)
data = np.array(df_1, dtype = float)

X_n = data[:, : ,0:12]
y_n = data[:, : , 12]
X_dummy, y_n = dim_reduction(X_n, y_n)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, LSTM
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, confusion_matrix

model = Sequential()
model.add(LSTM(units=64,input_shape=[X_n.shape[1],X_n.shape[2]], activation = 'relu', return_sequences = True))
model.add(Dropout(rate=0.1))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=6, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
def stratify(X,y,k):
    scores=[]
    f1=[]
    matrix=[]
    split = 1
    #m=0
    skf = StratifiedKFold(n_splits=k,random_state=None, shuffle=False)
    skf.get_n_splits(X,y)
    #print(skf)

    for train_index, test_index in skf.split(X, y):
        #print("TRAIN:", train_index, "TEST:", test_index)
        print('Split : === : ', split)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train,y_train,epochs=10, validation_data=(X_test,y_test),verbose=1)
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        scores.append(model.evaluate(X_test,y_test))
        f1.append(f1_score(y_test, y_pred, average='weighted'))
        matrix.append(confusion_matrix(y_test, y_pred)) 
        #m=confusion_matrix(y_test, y_pred) # overwrite the confusion matrix
        split+=1   
    return scores, f1, matrix

# %%
#Normal Validation
fold=10
scores, f1, matrix = stratify(X_n,y_n,fold)
# Out:
# Split : === :  1
# Epoch 1/10
# 115/115 [==============================] - 4s 27ms/step - loss: 1.9827 - accuracy: 0.7290 - val_loss: 8.8366 - val_accuracy: 0.7604
# Epoch 2/10
# 115/115 [==============================] - 3s 26ms/step - loss: 4.9431 - accuracy: 0.8238 - val_loss: 4.1858 - val_accuracy: 0.7946
# Epoch 3/10
# 115/115 [==============================] - 3s 26ms/step - loss: 1.0601 - accuracy: 0.8627 - val_loss: 2.9150 - val_accuracy: 0.7824
# Epoch 4/10
# 115/115 [==============================] - 3s 26ms/step - loss: 0.5918 - accuracy: 0.8862 - val_loss: 2.3405 - val_accuracy: 0.7848
# Epoch 5/10
# 115/115 [==============================] - 3s 26ms/step - loss: 0.5808 - accuracy: 0.8979 - val_loss: 1.5777 - val_accuracy: 0.8117
# Epoch 6/10
# 115/115 [==============================] - 3s 28ms/step - loss: 0.6062 - accuracy: 0.9017 - val_loss: 1.7377 - val_accuracy: 0.7995
# Epoch 7/10
# 115/115 [==============================] - 3s 28ms/step - loss: 0.5573 - accuracy: 0.9240 - val_loss: 1.3821 - val_accuracy: 0.8044
# Epoch 8/10
# 115/115 [==============================] - 3s 28ms/step - loss: 0.3279 - accuracy: 0.9352 - val_loss: 1.6142 - val_accuracy: 0.7971
# Epoch 9/10
# 115/115 [==============================] - 3s 28ms/step - loss: 0.2864 - accuracy: 0.9439 - val_loss: 2.6520 - val_accuracy: 0.7090
# Epoch 10/10
# 115/115 [==============================] - 3s 28ms/step - loss: 0.3257 - accuracy: 0.9431 - val_loss: 1.8133 - val_accuracy: 0.8142
# 13/13 [==============================] - 0s 7ms/step - loss: 1.8133 - accuracy: 0.8142
# Split : === :  2
# Epoch 1/10
# 115/115 [==============================] - 3s 29ms/step - loss: 0.5617 - accuracy: 0.9322 - val_loss: 0.4162 - val_accuracy: 0.9485
# Epoch 2/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.4722 - accuracy: 0.9390 - val_loss: 0.3449 - val_accuracy: 0.9412
# Epoch 3/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.3862 - accuracy: 0.9494 - val_loss: 0.3286 - val_accuracy: 0.8750
# Epoch 4/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.4224 - accuracy: 0.9510 - val_loss: 0.2315 - val_accuracy: 0.9412
# Epoch 5/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2768 - accuracy: 0.9592 - val_loss: 0.3025 - val_accuracy: 0.8824
# Epoch 6/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2776 - accuracy: 0.9600 - val_loss: 0.2557 - val_accuracy: 0.9559
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3145 - accuracy: 0.9660 - val_loss: 0.4903 - val_accuracy: 0.8529
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2425 - accuracy: 0.9722 - val_loss: 0.4105 - val_accuracy: 0.8652
# Epoch 9/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3742 - accuracy: 0.9676 - val_loss: 0.3965 - val_accuracy: 0.9387
# Epoch 10/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2140 - accuracy: 0.9755 - val_loss: 0.2504 - val_accuracy: 0.9510
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2504 - accuracy: 0.9510
# Split : === :  3
# Epoch 1/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.1267 - accuracy: 0.9692 - val_loss: 0.1154 - val_accuracy: 0.9632
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.1234 - accuracy: 0.9763 - val_loss: 0.1191 - val_accuracy: 0.9632
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.1116 - accuracy: 0.9801 - val_loss: 0.1332 - val_accuracy: 0.9559
# Epoch 4/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.0969 - accuracy: 0.9812 - val_loss: 0.1028 - val_accuracy: 0.9730
# Epoch 5/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.0857 - accuracy: 0.9842 - val_loss: 0.1122 - val_accuracy: 0.9583
# Epoch 6/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.0803 - accuracy: 0.9845 - val_loss: 0.1335 - val_accuracy: 0.9559
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0806 - accuracy: 0.9850 - val_loss: 0.1298 - val_accuracy: 0.9510
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0799 - accuracy: 0.9858 - val_loss: 0.1667 - val_accuracy: 0.9436
# Epoch 9/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0830 - accuracy: 0.9839 - val_loss: 0.1514 - val_accuracy: 0.9461
# Epoch 10/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0568 - accuracy: 0.9872 - val_loss: 0.1271 - val_accuracy: 0.9314
# 13/13 [==============================] - 0s 11ms/step - loss: 0.1271 - accuracy: 0.9314
# Split : === :  4
# Epoch 1/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0792 - accuracy: 0.9823 - val_loss: 0.0606 - val_accuracy: 0.9804
# Epoch 2/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0752 - accuracy: 0.9848 - val_loss: 0.0550 - val_accuracy: 0.9804
# Epoch 3/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0708 - accuracy: 0.9858 - val_loss: 0.0523 - val_accuracy: 0.9804
# Epoch 4/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0585 - accuracy: 0.9891 - val_loss: 0.0514 - val_accuracy: 0.9804
# Epoch 5/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0560 - accuracy: 0.9899 - val_loss: 0.0541 - val_accuracy: 0.9804
# Epoch 6/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0546 - accuracy: 0.9894 - val_loss: 0.0563 - val_accuracy: 0.9804
# Epoch 7/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0510 - accuracy: 0.9905 - val_loss: 0.0581 - val_accuracy: 0.9804
# Epoch 8/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0473 - accuracy: 0.9910 - val_loss: 0.0454 - val_accuracy: 0.9902
# Epoch 9/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.0443 - accuracy: 0.9924 - val_loss: 0.0660 - val_accuracy: 0.9804
# Epoch 10/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0467 - accuracy: 0.9913 - val_loss: 0.0687 - val_accuracy: 0.9804
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0687 - accuracy: 0.9804
# Split : === :  5
# Epoch 1/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0458 - accuracy: 0.9902 - val_loss: 0.0561 - val_accuracy: 0.9877
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0422 - accuracy: 0.9910 - val_loss: 0.0551 - val_accuracy: 0.9853
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0503 - accuracy: 0.9902 - val_loss: 0.0554 - val_accuracy: 0.9877
# Epoch 4/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0389 - accuracy: 0.9916 - val_loss: 0.0548 - val_accuracy: 0.9828
# Epoch 5/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0403 - accuracy: 0.9894 - val_loss: 0.0564 - val_accuracy: 0.9902
# Epoch 6/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0389 - accuracy: 0.9905 - val_loss: 0.1026 - val_accuracy: 0.9657
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0389 - accuracy: 0.9907 - val_loss: 0.0667 - val_accuracy: 0.9779
# Epoch 8/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0367 - accuracy: 0.9907 - val_loss: 0.0858 - val_accuracy: 0.9755
# Epoch 9/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0362 - accuracy: 0.9907 - val_loss: 0.0806 - val_accuracy: 0.9779
# Epoch 10/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0331 - accuracy: 0.9918 - val_loss: 0.0791 - val_accuracy: 0.9804
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0791 - accuracy: 0.9804
# Split : === :  6
# Epoch 1/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0465 - accuracy: 0.9875 - val_loss: 0.0291 - val_accuracy: 0.9951
# Epoch 2/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0714 - accuracy: 0.9807 - val_loss: 0.0632 - val_accuracy: 0.9828
# Epoch 3/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0622 - accuracy: 0.9818 - val_loss: 0.0740 - val_accuracy: 0.9804
# Epoch 4/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1026 - accuracy: 0.9725 - val_loss: 0.3499 - val_accuracy: 0.8922
# Epoch 5/10
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0739 - accuracy: 0.9804 - val_loss: 0.1957 - val_accuracy: 0.9461
# Epoch 6/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0684 - accuracy: 0.9856 - val_loss: 0.1819 - val_accuracy: 0.9412
# Epoch 7/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0275 - accuracy: 0.9948 - val_loss: 0.1732 - val_accuracy: 0.9412
# Epoch 8/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0210 - accuracy: 0.9962 - val_loss: 0.2463 - val_accuracy: 0.9289
# Epoch 9/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0196 - accuracy: 0.9959 - val_loss: 0.1956 - val_accuracy: 0.9461
# Epoch 10/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0342 - accuracy: 0.9962 - val_loss: 0.1777 - val_accuracy: 0.9583
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1777 - accuracy: 0.9583
# Split : === :  7
# Epoch 1/10
# 115/115 [==============================] - 6s 50ms/step - loss: 0.0444 - accuracy: 0.9886 - val_loss: 0.0230 - val_accuracy: 0.9926
# Epoch 2/10
# 115/115 [==============================] - 6s 49ms/step - loss: 0.0337 - accuracy: 0.9921 - val_loss: 0.0135 - val_accuracy: 0.9975
# Epoch 3/10
# 115/115 [==============================] - 5s 45ms/step - loss: 0.0266 - accuracy: 0.9951 - val_loss: 0.0179 - val_accuracy: 0.9975
# Epoch 4/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0335 - accuracy: 0.9943 - val_loss: 0.0198 - val_accuracy: 0.9975
# Epoch 5/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0257 - accuracy: 0.9943 - val_loss: 0.0210 - val_accuracy: 0.9975
# Epoch 6/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0223 - accuracy: 0.9959 - val_loss: 0.0186 - val_accuracy: 0.9975
# Epoch 7/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.0206 - accuracy: 0.9959 - val_loss: 0.0179 - val_accuracy: 0.9975
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0199 - accuracy: 0.9959 - val_loss: 0.0236 - val_accuracy: 0.9951
# Epoch 9/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.0196 - accuracy: 0.9959 - val_loss: 0.0186 - val_accuracy: 0.9975
# Epoch 10/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0199 - accuracy: 0.9959 - val_loss: 0.0173 - val_accuracy: 0.9975
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0173 - accuracy: 0.9975
# Split : === :  8
# Epoch 1/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0397 - accuracy: 0.9907 - val_loss: 0.0315 - val_accuracy: 0.9877
# Epoch 2/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0569 - accuracy: 0.9834 - val_loss: 0.0183 - val_accuracy: 0.9975
# Epoch 3/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.0333 - accuracy: 0.9910 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 4/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.0238 - accuracy: 0.9948 - val_loss: 0.0156 - val_accuracy: 0.9951
# Epoch 5/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0200 - accuracy: 0.9959 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 6/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0188 - accuracy: 0.9959 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 7/10
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0188 - accuracy: 0.9959 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 8/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0186 - accuracy: 0.9959 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 9/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0182 - accuracy: 0.9959 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 10/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.0180 - accuracy: 0.9959 - val_loss: 0.0032 - val_accuracy: 1.0000
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0032 - accuracy: 1.0000
# Split : === :  9
# Epoch 1/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0525 - accuracy: 0.9956 - val_loss: 0.0102 - val_accuracy: 0.9975
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0216 - accuracy: 0.9954 - val_loss: 0.0129 - val_accuracy: 0.9975
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0258 - accuracy: 0.9935 - val_loss: 0.0123 - val_accuracy: 0.9951
# Epoch 4/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0216 - accuracy: 0.9943 - val_loss: 0.0088 - val_accuracy: 0.9975
# Epoch 5/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0203 - accuracy: 0.9948 - val_loss: 0.0080 - val_accuracy: 0.9975
# Epoch 6/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0192 - accuracy: 0.9948 - val_loss: 0.0045 - val_accuracy: 0.9975
# Epoch 7/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.1922 - accuracy: 0.9426 - val_loss: 0.6167 - val_accuracy: 0.7941
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2768 - accuracy: 0.9112 - val_loss: 0.1915 - val_accuracy: 0.9534
# Epoch 9/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.1034 - accuracy: 0.9654 - val_loss: 0.0410 - val_accuracy: 0.9853
# Epoch 10/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0716 - accuracy: 0.9790 - val_loss: 0.0390 - val_accuracy: 0.9828
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0390 - accuracy: 0.9828
# Split : === :  10
# Epoch 1/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0406 - accuracy: 0.9886 - val_loss: 0.0544 - val_accuracy: 0.9853
# Epoch 2/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0437 - accuracy: 0.9905 - val_loss: 0.0662 - val_accuracy: 0.9755
# Epoch 3/10
# 115/115 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.98 - 4s 37ms/step - loss: 0.0504 - accuracy: 0.9883 - val_loss: 0.0390 - val_accuracy: 0.9828
# Epoch 4/10
# 115/115 [==============================] - 4s 38ms/step - loss: 50.6685 - accuracy: 0.9747 - val_loss: 11737.7373 - val_accuracy: 0.3725
# Epoch 5/10
# 115/115 [==============================] - 4s 38ms/step - loss: 761763136.0000 - accuracy: 0.5497 - val_loss: 2352.4883 - val_accuracy: 0.6103
# Epoch 6/10
# 115/115 [==============================] - 4s 38ms/step - loss: 2098.5789 - accuracy: 0.6616 - val_loss: 164060.8438 - val_accuracy: 0.6422
# Epoch 7/10
# 115/115 [==============================] - 4s 36ms/step - loss: 169079.9688 - accuracy: 0.6796 - val_loss: 500542.4062 - val_accuracy: 0.6887
# Epoch 8/10
# 115/115 [==============================] - 4s 34ms/step - loss: 192879.1406 - accuracy: 0.6885 - val_loss: 484985.2812 - val_accuracy: 0.7230
# Epoch 9/10
# 115/115 [==============================] - 4s 33ms/step - loss: 188894.1719 - accuracy: 0.6973 - val_loss: 471943.9688 - val_accuracy: 0.7181
# Epoch 10/10
# 115/115 [==============================] - 4s 33ms/step - loss: 177989.0938 - accuracy: 0.6975 - val_loss: 465917.4375 - val_accuracy: 0.7206
# 13/13 [==============================] - 0s 10ms/step - loss: 465917.4375 - accuracy: 0.7206

# %%
scores = np.array(scores)
score_acc = scores[:,-1]
f1_scores = np.array(f1)
print('Normal Cross Validation with',fold, 'folds, Model : LSTM')
print('Accuracy : %0.4f' %score_acc.mean())
print('F1_score : %0.4f' %f1_scores.mean())
# Out:
# Normal Cross Validation with 10 folds, Model : LSTM
# Accuracy : 0.9317
# F1_score : 0.9297

# %%
#Per Participant Cross Validation
#Subject 1
df_sub1, df_subj_1 = sliding_window_samples(d1_s1, window_length, overlap)
data_s1 = np.array(df_sub1, dtype = float)

X_s1 = data_s1[:, : ,0:12]
y_s1 = data_s1[:, : , 12]
X_dummy, y_s1 = dim_reduction(X_s1, y_s1)

fold=4
scores, f1, matrix = stratify(X_s1,y_s1,fold)
# Out:
# Split : === :  1
# Epoch 1/10
# 43/43 [==============================] - 2s 31ms/step - loss: 3.9949 - accuracy: 0.7564 - val_loss: 5498.6309 - val_accuracy: 0.8136
# Epoch 2/10
# 43/43 [==============================] - 1s 27ms/step - loss: 50658.2070 - accuracy: 0.8405 - val_loss: 0.6975 - val_accuracy: 0.7939
# Epoch 3/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3229 - accuracy: 0.9071 - val_loss: 0.6555 - val_accuracy: 0.8333
# Epoch 4/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1598 - accuracy: 0.9473 - val_loss: 0.6994 - val_accuracy: 0.8114
# Epoch 5/10
# 43/43 [==============================] - 1s 27ms/step - loss: 25.2200 - accuracy: 0.9568 - val_loss: 0.7427 - val_accuracy: 0.8202
# Epoch 6/10
# 43/43 [==============================] - 1s 27ms/step - loss: 5.8423 - accuracy: 0.9437 - val_loss: 1.2834 - val_accuracy: 0.8377
# Epoch 7/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1299 - accuracy: 0.9649 - val_loss: 1.2661 - val_accuracy: 0.8289
# Epoch 8/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1074 - accuracy: 0.9751 - val_loss: 1.2641 - val_accuracy: 0.8180
# Epoch 9/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0827 - accuracy: 0.9817 - val_loss: 1.3044 - val_accuracy: 0.8202
# Epoch 10/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0721 - accuracy: 0.9890 - val_loss: 1.2869 - val_accuracy: 0.8246
# 15/15 [==============================] - 0s 7ms/step - loss: 1.2869 - accuracy: 0.8246
# Split : === :  2
# Epoch 1/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.4633 - accuracy: 0.9305 - val_loss: 0.1197 - val_accuracy: 0.9693
# Epoch 2/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1855 - accuracy: 0.9503 - val_loss: 0.1560 - val_accuracy: 0.9474
# Epoch 3/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1367 - accuracy: 0.9598 - val_loss: 0.1780 - val_accuracy: 0.9320
# Epoch 4/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1127 - accuracy: 0.9715 - val_loss: 0.1630 - val_accuracy: 0.9364
# Epoch 5/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1002 - accuracy: 0.9744 - val_loss: 0.1874 - val_accuracy: 0.9254
# Epoch 6/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0877 - accuracy: 0.9788 - val_loss: 0.2031 - val_accuracy: 0.9232
# Epoch 7/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0748 - accuracy: 0.9832 - val_loss: 0.1973 - val_accuracy: 0.9320
# Epoch 8/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0684 - accuracy: 0.9868 - val_loss: 0.2090 - val_accuracy: 0.9254
# Epoch 9/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0591 - accuracy: 0.9890 - val_loss: 0.1892 - val_accuracy: 0.9364
# Epoch 10/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0586 - accuracy: 0.9905 - val_loss: 0.2437 - val_accuracy: 0.9189
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2437 - accuracy: 0.9189
# Split : === :  3
# Epoch 1/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.1127 - accuracy: 0.9685 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 2/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0870 - accuracy: 0.9817 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 3/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0748 - accuracy: 0.9817 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 4/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0637 - accuracy: 0.9868 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 5/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0583 - accuracy: 0.9912 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 6/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0576 - accuracy: 0.9876 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 7/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0494 - accuracy: 0.9941 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 8/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0477 - accuracy: 0.9956 - val_loss: 0.0218 - val_accuracy: 0.9978
# Epoch 9/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0438 - accuracy: 0.9949 - val_loss: 0.0168 - val_accuracy: 0.9978
# Epoch 10/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0439 - accuracy: 0.9956 - val_loss: 0.0189 - val_accuracy: 0.9978
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0189 - accuracy: 0.9978
# Split : === :  4
# Epoch 1/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0353 - accuracy: 0.9949 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 2/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0296 - accuracy: 0.9971 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 3/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0274 - accuracy: 0.9971 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 4/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0255 - accuracy: 0.9963 - val_loss: 0.0416 - val_accuracy: 0.9978
# Epoch 5/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9978
# Epoch 6/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0210 - accuracy: 0.9993 - val_loss: 0.0479 - val_accuracy: 0.9956
# Epoch 7/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0210 - accuracy: 0.9993 - val_loss: 0.0525 - val_accuracy: 0.9912
# Epoch 8/10
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0183 - accuracy: 0.9985 - val_loss: 0.0544 - val_accuracy: 0.9912
# Epoch 9/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 0.9912
# Epoch 10/10
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9846
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0603 - accuracy: 0.9846

# %%
scores = np.array(scores)
score_acc = scores[:,-1]
f1_scores = np.array(f1)
print('SUB 1 Cross Validation with',fold, 'folds, Model : LSTM')
print('Accuracy : %0.4f' %score_acc.mean())
print('F1_score : %0.4f' %f1_scores.mean())
# Out:
# SUB 1 Cross Validation with 4 folds, Model : LSTM
# Accuracy : 0.9315
# F1_score : 0.9303

# %%
#Subject 2
df_sub2, df_subj_2 = sliding_window_samples(d2_s2, window_length, overlap)
data_s2 = np.array(df_sub2, dtype = float)

X_s2 = data_s2[:, : ,0:12]
y_s2 = data_s2[:, : , 12]
X_dummy, y_s2 = dim_reduction(X_s2,y_s2)

fold=7
scores, f1, matrix = stratify(X_s2,y_s2,fold)
# Out:
# Split : === :  1
# Epoch 1/10
# 61/61 [==============================] - 3s 29ms/step - loss: 21.5285 - accuracy: 0.7156 - val_loss: 0.9947 - val_accuracy: 0.6873
# Epoch 2/10
# 61/61 [==============================] - 2s 26ms/step - loss: 12.4908 - accuracy: 0.9028 - val_loss: 0.8980 - val_accuracy: 0.7616
# Epoch 3/10
# 61/61 [==============================] - 2s 26ms/step - loss: 0.3317 - accuracy: 0.9204 - val_loss: 0.9291 - val_accuracy: 0.7585
# Epoch 4/10
# 61/61 [==============================] - 2s 26ms/step - loss: 0.1839 - accuracy: 0.9540 - val_loss: 0.9156 - val_accuracy: 0.7678
# Epoch 5/10
# 61/61 [==============================] - 2s 27ms/step - loss: 0.1325 - accuracy: 0.9726 - val_loss: 0.9516 - val_accuracy: 0.7709
# Epoch 6/10
# 61/61 [==============================] - 2s 33ms/step - loss: 0.1146 - accuracy: 0.9690 - val_loss: 0.9955 - val_accuracy: 0.7647
# Epoch 7/10
# 61/61 [==============================] - 2s 33ms/step - loss: 0.0918 - accuracy: 0.9788 - val_loss: 1.0581 - val_accuracy: 0.7802
# Epoch 8/10
# 61/61 [==============================] - 2s 33ms/step - loss: 0.0632 - accuracy: 0.9912 - val_loss: 1.0971 - val_accuracy: 0.7399
# Epoch 9/10
# 61/61 [==============================] - 2s 33ms/step - loss: 0.0532 - accuracy: 0.9917 - val_loss: 1.1238 - val_accuracy: 0.7802
# Epoch 10/10
# 61/61 [==============================] - 2s 32ms/step - loss: 0.0453 - accuracy: 0.9917 - val_loss: 1.1806 - val_accuracy: 0.7771
# 11/11 [==============================] - 0s 9ms/step - loss: 1.1806 - accuracy: 0.7771
# Split : === :  2
# Epoch 1/10
# 61/61 [==============================] - 2s 33ms/step - loss: 0.2235 - accuracy: 0.9483 - val_loss: 0.0470 - val_accuracy: 0.9938
# Epoch 2/10
# 61/61 [==============================] - 2s 33ms/step - loss: 0.1340 - accuracy: 0.9638 - val_loss: 0.0544 - val_accuracy: 0.9876
# Epoch 3/10
# 61/61 [==============================] - 2s 34ms/step - loss: 0.0937 - accuracy: 0.9757 - val_loss: 0.0533 - val_accuracy: 0.9938
# Epoch 4/10
# 61/61 [==============================] - 2s 36ms/step - loss: 0.0658 - accuracy: 0.9840 - val_loss: 0.0668 - val_accuracy: 0.9876
# Epoch 5/10
# 61/61 [==============================] - 2s 37ms/step - loss: 0.0441 - accuracy: 0.9912 - val_loss: 0.0570 - val_accuracy: 0.9876
# Epoch 6/10
# 61/61 [==============================] - 2s 39ms/step - loss: 0.0342 - accuracy: 0.9964 - val_loss: 0.0593 - val_accuracy: 0.9814
# Epoch 7/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0596 - accuracy: 0.9943 - val_loss: 0.1226 - val_accuracy: 0.9659
# Epoch 8/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0423 - accuracy: 0.9959 - val_loss: 0.0859 - val_accuracy: 0.9814
# Epoch 9/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0299 - accuracy: 0.9990 - val_loss: 0.0713 - val_accuracy: 0.9752
# Epoch 10/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0229 - accuracy: 0.9995 - val_loss: 0.0733 - val_accuracy: 0.9783
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0733 - accuracy: 0.9783
# Split : === :  3
# Epoch 1/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0309 - accuracy: 0.9959 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 2/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0250 - accuracy: 0.9990 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 3/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 4/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 5/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 6/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 7/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 8/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9969
# Epoch 10/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9969
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0147 - accuracy: 0.9969
# Split : === :  4
# Epoch 1/10
# 61/61 [==============================] - 3s 46ms/step - loss: 0.0097 - accuracy: 0.9990 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 2/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0626 - accuracy: 0.9974 - val_loss: 0.0302 - val_accuracy: 0.9938
# Epoch 3/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0384 - accuracy: 0.9922 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 4/10
# 61/61 [==============================] - 3s 46ms/step - loss: 0.0261 - accuracy: 0.9959 - val_loss: 0.0315 - val_accuracy: 0.9938
# Epoch 5/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 6/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 7/10
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 8/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9969
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9938
# Epoch 10/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 1.0000
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0234 - accuracy: 1.0000
# Split : === :  5
# Epoch 1/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 2/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 3/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 4/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 5/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 6/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 7/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 8/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 10/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0055 - accuracy: 1.0000
# Split : === :  6
# Epoch 1/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 7.4681e-04 - val_accuracy: 1.0000
# Epoch 2/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 7.6931e-04 - val_accuracy: 1.0000
# Epoch 3/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 7.7518e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 7.2927e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 7.9529e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 7.3391e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 61/61 [==============================] - 2s 39ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 7.7882e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 8.6517e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 8.9294e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.0396e-04 - val_accuracy: 1.0000
# 11/11 [==============================] - 0s 10ms/step - loss: 7.0396e-04 - accuracy: 1.0000
# Split : === :  7
# Epoch 1/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 2/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 3/10
# 61/61 [==============================] - 2s 40ms/step - loss: 9.4433e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 4/10
# 61/61 [==============================] - 2s 40ms/step - loss: 9.8852e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 5/10
# 61/61 [==============================] - 2s 40ms/step - loss: 8.2639e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 6/10
# 61/61 [==============================] - 2s 40ms/step - loss: 8.9954e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 7/10
# 61/61 [==============================] - 2s 40ms/step - loss: 7.9648e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 8/10
# 61/61 [==============================] - 2s 40ms/step - loss: 7.7397e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9969
# Epoch 9/10
# 61/61 [==============================] - 2s 40ms/step - loss: 7.1944e-04 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9969
# Epoch 10/10
# 61/61 [==============================] - 2s 40ms/step - loss: 6.1418e-04 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9969
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0099 - accuracy: 0.9969

# %%
scores = np.array(scores)
score_acc = scores[:,-1]
f1_scores = np.array(f1)
print('SUB 2 Cross Validation with',fold, 'folds, Model : LSTM')
print('Accuracy : %0.4f' %score_acc.mean())
print('F1_score : %0.4f' %f1_scores.mean())
# Out:
# SUB 2 Cross Validation with 7 folds, Model : LSTM
# Accuracy : 0.9642
# F1_score : 0.9642
