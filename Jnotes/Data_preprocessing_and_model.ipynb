# %% [markdown]
# ### NISHANTH IRUTHAYARAJ
# Matric. No: 1522044

# %% [markdown]
# **Data Preprocessing**

# %%
import pandas as pd
import numpy as np

#Reading files and Correcting Timestamp#
c_heads = ['Time', 'Device', 'e1' , 'e2' , 'e3' , 'e4' , 'e5' , 'e6' ,'Label']
df_sub1_esense = pd.read_csv('eSense_sbj1.csv', names = c_heads)
df_sub1_esense['Time'] = pd.to_datetime(df_sub1_esense['Time'], unit = 'ms') + pd.Timedelta('02:00:00')
df_sub1_esense = df_sub1_esense.set_index('Time').resample('10L', offset = 4000000).first().interpolate()
df_sub1_esense = df_sub1_esense.sort_index()

df_sub2_esense = pd.read_csv('eSense_sbj2.csv', names = c_heads)
df_sub2_esense['Time'] = pd.to_datetime(df_sub2_esense['Time'], unit = 'ms') + pd.Timedelta('02:00:00')
df_sub2_esense = df_sub2_esense.set_index('Time').resample('10L', offset = 4000000).first().interpolate()
df_sub2_esense = df_sub2_esense.sort_index()

# %%
#Data Interpolating and Upsampling
#Subject 1 ankle
df_layup1_ankle = pd.read_csv('layup_sbj1_ankle.csv', index_col = 0, comment= ';')
df_layup1_ankle.index = pd.date_range(start = '2021-04-14 18:22:13.554', periods = df_layup1_ankle.shape[0], freq = "10.869565L")
df_layup1_ankle = df_layup1_ankle.resample('10L', offset = 4000000).first().interpolate()

df_movements1_ankle_1 = pd.read_csv('movements_sbj1_ankle_1.csv', index_col = 0, comment= ';')
df_movements1_ankle_1.index = pd.date_range(start = '2021-04-14 18:42:32.024', periods = df_movements1_ankle_1.shape[0], freq = "10.869565L")
df_movements1_ankle_1 = df_movements1_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_shooting1_ankle_1 = pd.read_csv('shooting_sbj1_ankle.csv', index_col = 0, comment= ';')
df_shooting1_ankle_1.index = pd.date_range(start = '2021-04-14 18:12:54.024', periods = df_shooting1_ankle_1.shape[0], freq = "10.869565L")
df_shooting1_ankle_1 = df_shooting1_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_sub1_ankle = pd.concat([df_layup1_ankle,df_movements1_ankle_1,df_shooting1_ankle_1])
df_sub1_ankle = df_sub1_ankle.set_axis(['a1', 'a2', 'a3'], axis = 'columns')
#df_sub1_ankle = df_sub1_ankle.sort_index()

#Subject 2 ankle
df_dribbling2_ankle = pd.read_csv('dribbling_sbj2_ankle.csv', index_col = 0, comment= ';')
df_dribbling2_ankle.index = pd.date_range(start = '2021-04-14 19:26:42.914', periods = df_dribbling2_ankle.shape[0], freq = "10.869565L")
df_dribbling2_ankle = df_dribbling2_ankle.resample('10L', offset = 4000000).first().interpolate()

df_layup2_ankle = pd.read_csv('layup_sbj2_ankle.csv', index_col = 0, comment= ';')
df_layup2_ankle.index = pd.date_range(start = '2021-04-14 19:16:25.794', periods = df_layup2_ankle.shape[0], freq = "10.869565L")
df_layup2_ankle = df_layup2_ankle.resample('10L', offset = 4000000).first().interpolate()

df_movements2_ankle_1 = pd.read_csv('movements_sbj2_ankle_1.csv', index_col = 0, comment= ';') 
df_movements2_ankle_1.index = pd.date_range(start = '2021-04-14 19:36:19.244', periods = df_movements2_ankle_1.shape[0], freq = "10.869565L")
df_movements2_ankle_1 = df_movements2_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_shooting2_ankle_1 = pd.read_csv('shooting_sbj2_ankle_1.csv', index_col = 0, comment= ';')
df_shooting2_ankle_1.index = pd.date_range(start = '2021-04-14 18:55:50.364', periods = df_shooting2_ankle_1.shape[0], freq = "10.869565L")
df_shooting2_ankle_1 = df_shooting2_ankle_1.resample('10L', offset = 4000000).first().interpolate()

df_sub2_ankle = pd.concat([df_dribbling2_ankle, df_layup2_ankle, df_movements2_ankle_1, df_shooting2_ankle_1])
df_sub2_ankle = df_sub2_ankle.set_axis(['a1','a2','a3'], axis = 'columns')
#df_sub2_ankle = df_sub2_ankle.sort_index()

# %%
#Subject 1 wrist
df_layup1_wrist = pd.read_csv('layup_sbj1_wrist.csv', index_col = 0, comment= ';')
df_layup1_wrist.index = pd.date_range(start = '2021-04-14 18:22:52.524', periods = df_layup1_wrist.shape[0], freq = "10.869565L")
df_layup1_wrist = df_layup1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_movements1_wrist = pd.read_csv('movements_sbj1_wrist.csv', index_col = 0, comment= ';')
df_movements1_wrist.index = pd.date_range(start = '2021-04-14 18:42:05.244', periods = df_movements1_wrist.shape[0], freq = "10.869565L")
df_movements1_wrist = df_movements1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_shooting1_wrist = pd.read_csv('shooting_sbj1_wrist.csv', index_col = 0, comment= ';')
df_shooting1_wrist.index = pd.date_range(start = '2021-04-14 18:13:12.834', periods = df_shooting1_wrist.shape[0], freq = "10.869565L")
df_shooting1_wrist = df_shooting1_wrist.resample('10L', offset = 4000000).first().interpolate()

df_sub1_wrist = pd.concat([df_layup1_wrist, df_movements1_wrist, df_shooting1_wrist])
df_sub1_wrist = df_sub1_wrist.set_axis(['w1','w2','w3'], axis = 'columns')
#df_sub1_wrist = df_sub1_wrist.sort_index()

#Subject 2 wrist
df_dribbling2_wrist = pd.read_csv('dribbling_sbj2_wrist.csv', index_col = 0, comment= ';')
df_dribbling2_wrist.index = pd.date_range(start = '2021-04-14 19:26:24.464', periods = df_dribbling2_wrist.shape[0], freq = "10.869565L")
df_dribbling2_wrist = df_dribbling2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_layup2_wrist = pd.read_csv('layup_sbj2_wrist.csv', index_col = 0, comment= ';')
df_layup2_wrist.index = pd.date_range(start = '2021-04-14 19:16:05.604', periods = df_layup2_wrist.shape[0], freq = "10.869565L")
df_layup2_wrist = df_layup2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_movements2_wrist = pd.read_csv('movements_sbj2_wrist.csv', index_col = 0, comment= ';') 
df_movements2_wrist.index = pd.date_range(start = '2021-04-14 19:36:45.074', periods = df_movements2_wrist.shape[0], freq = "10.869565L")
df_movements2_wrist = df_movements2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_shooting2_wrist = pd.read_csv('shooting_sbj2_wrist.csv', index_col = 0, comment= ';')
df_shooting2_wrist.index = pd.date_range(start = '2021-04-14 18:56:21.474', periods = df_shooting2_wrist.shape[0], freq = "10.869565L")
df_shooting2_wrist = df_shooting2_wrist.resample('10L',  offset = 4000000).first().interpolate()

df_sub2_wrist = pd.concat([df_dribbling2_wrist, df_layup2_wrist, df_movements2_wrist, df_shooting2_wrist])
df_sub2_wrist = df_sub2_wrist.set_axis(['w1','w2','w3'], axis = 'columns')
#df_sub2_wrist = df_sub2_wrist.sort_index()

# %%
#Merging and Normalising
df_sub1 = df_sub1_esense.merge(df_sub1_ankle, left_index=True, right_index=True)
df_1 = df_sub1.merge(df_sub1_wrist, left_index=True, right_index=True)
df_1 = (df_1 - df_1.mean()) / df_1.std()
df_1 = df_1.drop(['Device'], axis = 1)

df_sub2 = df_sub2_esense.merge(df_sub2_ankle, left_index=True, right_index=True)
df_2 = df_sub2.merge(df_sub2_wrist, left_index=True, right_index=True)
df_2 = (df_2 - df_2.mean()) / df_2.std()
df_2 = df_2.drop(['Device'], axis = 1)

# %%
#Finding Samples for Time Intersection
intersection_1 = [df_1.index.isin(df_1.between_time('18:23:14', '18:25:28').index),
                  df_1.index.isin(df_1.between_time('18:45:17', '18:47:16').index),
                  df_1.index.isin(df_1.between_time('18:13:25', '18:15:47').index),
                  df_1.index.isin(df_1.between_time('18:42:48', '18:45:17').index)]
activity_1 = ['layup', 'running', 'shooting', 'walking']
df_1['Label'] = np.select(intersection_1, activity_1, 'Null')
df_1['Subjects'] = 'Subject1'
df_1 = df_1[['e1','e2','e3','e4','e5','e6','a1','a2','a3','w1','w2','w3','Label','Subjects']]

intersection_2 = [df_2.index.isin(df_2.between_time('19:26:58', '19:29:59').index), 
                df_2.index.isin(df_2.between_time('19:17:35', '19:20:14').index),
                df_2.index.isin(df_2.between_time('19:39:47', '19:41:55').index),
                df_2.index.isin(df_2.between_time('19:00:14', '19:02:12').index),
                df_2.index.isin(df_2.between_time('19:37:15', '19:39:46').index)]
activity_2 = ['dribbling', 'layup', 'running', 'shooting', 'walking']
df_2['Label'] = np.select(intersection_2, activity_2, 'Null')
df_2['Subjects'] = 'Subject2'
df_2 = df_2[['e1','e2','e3','e4','e5','e6','a1','a2','a3','w1','w2','w3','Label','Subjects']]

df = pd.concat([df_1, df_2])
df.reset_index(drop=True, inplace=True)
df.to_csv('df_activity.csv')

# %%
#Importing and Label Encoding 
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('df_activity.csv', index_col = 0)
label = LabelEncoder()
df['Label'] = label.fit_transform(df['Label'].values)

df_new = df.drop(['Subjects'], axis = 1)

df_s1 = df.loc[df['Subjects'] == 'Subject1']
d1_s1 = df_s1.drop(['Subjects'], axis = 1)

df_s2 = df.loc[df['Subjects'] == 'Subject2']
d2_s2 = df_s2.drop(['Subjects'], axis = 1)

window_length = 100
overlap = 60

# %%
#Sliding Window
def sliding_window_samples(data, samples_per_window, overlap_ratio):
    """
    Return a sliding window measured in number of samples over a data array.

    :param data: input array, can be numpy or pandas dataframe
    :param samples_per_window: window length as number of samples per window
    :param overlap_ratio: overlap is meant as percentage and should be an integer value
    :return: tuple of windows and indices
    """
    windows = []
    indices = []
    curr = 0
    win_len = samples_per_window
    if overlap_ratio is not None:
        overlapping_elements = int((overlap_ratio / 100) * (win_len))
        if overlapping_elements >= win_len:
            print('Number of overlapping elements exceeds window size.')
            return
    while curr < len(data) - win_len:
        windows.append(data[curr:curr + win_len])
        indices.append([curr, curr + win_len])
        curr = curr + win_len - overlapping_elements
    try:
        result_windows = np.array(windows)
        result_indices = np.array(indices)
    except:
        result_windows = np.empty(shape=(len(windows), win_len, data.shape[1]), dtype=object)
        result_indices = np.array(indices)
        for i in range(0, len(windows)):
            result_windows[i] = windows[i]
            result_indices[i] = indices[i]

    return result_windows, result_indices

# %%
#Dimension Reduction for Model
def dim_reduction(x,s):
    axis = 1
    x_new = np.reshape(x, (x.shape[0], -1))
    y, indices = np.unique(s, return_inverse=True)
    y_new = y[np.argmax(np.apply_along_axis(np.bincount, axis, indices.reshape(s.shape),None, np.max(indices) + 1), axis=axis)]
    return x_new, y_new

# %% [markdown]
# **KNN Model**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold, cross_val_score

def model(features, target, score):
    knn = KNeighborsClassifier(n_neighbors = 3,  p = 2)
    kfold = KFold(n_splits = 10, random_state=42, shuffle=True)
    scores = cross_val_score(knn, features, target, cv = kfold, scoring = score, n_jobs = -1)
    return scores.mean()

# %%
#Normal Cross Validation for KNN
df_1, df_2 = sliding_window_samples(df_new, window_length, overlap)
data = np.array(df_1, dtype = float)

X_data = data[:, : ,0:12]
y_data = data[:, : , 12]
X_n, y_n = dim_reduction(X_data, y_data)

print('Normal Cross Validation with 10 folds, Model : KNN')
print('Mean_accuracy: %.3f' % model(X_n, y_n, 'accuracy'))
print('Mean_precision_score: %.3f' % model(X_n, y_n, 'precision_weighted'))
print('Mean_recall_score: %.3f' % model(X_n, y_n, 'recall_weighted'))
print('Mean_F1_score: %.3f' % model(X_n, y_n, 'f1_weighted'))
# Out:
# Normal Cross Validation with 10 folds, Model : KNN
# Mean_accuracy: 0.726
# Mean_precision_score: 0.787
# Mean_recall_score: 0.726
# Mean_F1_score: 0.703

# %%
#Per Participant Cross Validation for KNN
#Subject 1
df_sub1, df_subj_1 = sliding_window_samples(d1_s1, window_length, overlap)
data_s1 = np.array(df_sub1, dtype = float)

X_s1 = data_s1[:, : ,0:12]
y_s1 = data_s1[:, : , 12]
X_sub1, y_sub1 = dim_reduction(X_s1, y_s1)

print('SUB 1 Cross Validation with 10 folds, Model : KNN')
print('Mean_accuracy_s1: %.3f' % model(X_sub1, y_sub1, 'accuracy'))
print('Mean_precision_score_s1: %.3f' % model(X_sub1, y_sub1, 'precision_weighted'))
print('Mean_recall_score_s1: %.3f' % model(X_sub1, y_sub1, 'recall_weighted'))
print('Mean_F1_score_s1: %.3f' % model(X_sub1, y_sub1, 'f1_weighted'))
# Out:
# SUB 1 Cross Validation with 10 folds, Model : KNN
# Mean_accuracy_s1: 0.753
# Mean_precision_score_s1: 0.811
# Mean_recall_score_s1: 0.753
# Mean_F1_score_s1: 0.738

# %%
#Subject 2
df_sub2, df_subj_2 = sliding_window_samples(d2_s2, window_length, overlap)
data_s2 = np.array(df_sub2, dtype = float)

X_s2 = data_s2[:, : ,0:12]
y_s2 = data_s2[:, : , 12]
X_sub2, y_sub2 = dim_reduction(X_s2, y_s2)

print('SUB 2 Cross Validation with 10 folds, Model : KNN')
print('Mean_accuracy_s2: %.3f' % model(X_sub2, y_sub2, 'accuracy'))
print('Mean_precision_score_s2: %.3f' % model(X_sub2, y_sub2, 'precision_weighted'))
print('Mean_recall_score_s2: %.3f' % model(X_sub2, y_sub2, 'recall_weighted'))
print('Mean_F1_score_s2: %.3f' % model(X_sub2, y_sub2, 'f1_weighted'))
# Out:
# SUB 2 Cross Validation with 10 folds, Model : KNN
# Mean_accuracy_s2: 0.754
# Mean_precision_score_s2: 0.798
# Mean_recall_score_s2: 0.754
# Mean_F1_score_s2: 0.715

# %% [markdown]
# **LSTM model**

# %%
df_1, df_2 = sliding_window_samples(df_new, window_length, overlap)
data = np.array(df_1, dtype = float)

X_n = data[:, : ,0:12]
y_n = data[:, : , 12]
X_dummy, y_n = dim_reduction(X_n, y_n)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, LSTM
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, confusion_matrix

model = Sequential()
model.add(LSTM(units=64,input_shape=[X_n.shape[1],X_n.shape[2]], activation = 'relu', return_sequences = True))
model.add(Dropout(rate=0.1))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=6, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
def stratify(X,y,k):
    scores=[]
    f1=[]
    matrix=[]
    split = 1
    #m=0
    skf = StratifiedKFold(n_splits=k,random_state=None, shuffle=False)
    skf.get_n_splits(X,y)
    #print(skf)

    for train_index, test_index in skf.split(X, y):
        #print("TRAIN:", train_index, "TEST:", test_index)
        print('Split : === : ', split)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train,y_train,epochs=10, validation_data=(X_test,y_test),verbose=1)
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        scores.append(model.evaluate(X_test,y_test))
        f1.append(f1_score(y_test, y_pred, average='weighted'))
        matrix.append(confusion_matrix(y_test, y_pred)) 
        #m=confusion_matrix(y_test, y_pred) # overwrite the confusion matrix
        split+=1   
    return scores, f1, matrix

# %%
#Normal Validation
fold=10
scores, f1, matrix = stratify(X_n,y_n,fold)
# Out:
# Split : === :  1
# Epoch 1/10
# 115/115 [==============================] - 4s 28ms/step - loss: 0.7008 - accuracy: 0.7879 - val_loss: 0.6720 - val_accuracy: 0.7946
# Epoch 2/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.3005 - accuracy: 0.9058 - val_loss: 0.7213 - val_accuracy: 0.7800
# Epoch 3/10
# 115/115 [==============================] - 5s 41ms/step - loss: 568713.1250 - accuracy: 0.8252 - val_loss: 2899.7351 - val_accuracy: 0.3619
# Epoch 4/10
# 115/115 [==============================] - 5s 40ms/step - loss: 428.5832 - accuracy: 0.5844 - val_loss: 1.0770 - val_accuracy: 0.6112
# Epoch 5/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.8629 - accuracy: 0.6808 - val_loss: 0.9720 - val_accuracy: 0.6381
# Epoch 6/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.6884 - accuracy: 0.7141 - val_loss: 0.9252 - val_accuracy: 0.6553
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.6234 - accuracy: 0.7977 - val_loss: 0.9165 - val_accuracy: 0.7506
# Epoch 8/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.5704 - accuracy: 0.8342 - val_loss: 0.8910 - val_accuracy: 0.7555
# Epoch 9/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.5572 - accuracy: 0.8399 - val_loss: 0.8698 - val_accuracy: 0.7531
# Epoch 10/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.5723 - accuracy: 0.8423 - val_loss: 0.8507 - val_accuracy: 0.7531
# 13/13 [==============================] - 0s 10ms/step - loss: 0.8507 - accuracy: 0.7531
# Split : === :  2
# Epoch 1/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.5253 - accuracy: 0.8402 - val_loss: 0.5380 - val_accuracy: 0.8309
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.5084 - accuracy: 0.8497 - val_loss: 0.5283 - val_accuracy: 0.8382
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.5416 - accuracy: 0.8497 - val_loss: 0.5255 - val_accuracy: 0.8309
# Epoch 4/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.4648 - accuracy: 0.8557 - val_loss: 0.5273 - val_accuracy: 0.8211
# Epoch 5/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.4592 - accuracy: 0.8633 - val_loss: 0.5231 - val_accuracy: 0.8186
# Epoch 6/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.4194 - accuracy: 0.8685 - val_loss: 0.5089 - val_accuracy: 0.8211
# Epoch 7/10
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4145 - accuracy: 0.8710 - val_loss: 0.5061 - val_accuracy: 0.8260
# Epoch 8/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.3956 - accuracy: 0.8731 - val_loss: 0.5189 - val_accuracy: 0.8186
# Epoch 9/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.3843 - accuracy: 0.8791 - val_loss: 0.5342 - val_accuracy: 0.7917
# Epoch 10/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3841 - accuracy: 0.8835 - val_loss: 0.5043 - val_accuracy: 0.8162
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5043 - accuracy: 0.8162
# Split : === :  3
# Epoch 1/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.3808 - accuracy: 0.8808 - val_loss: 0.3955 - val_accuracy: 0.8480
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3572 - accuracy: 0.8832 - val_loss: 0.3987 - val_accuracy: 0.8456
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3399 - accuracy: 0.8889 - val_loss: 0.4100 - val_accuracy: 0.8358
# Epoch 4/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3388 - accuracy: 0.8916 - val_loss: 0.4021 - val_accuracy: 0.8382
# Epoch 5/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.3291 - accuracy: 0.8925 - val_loss: 0.4117 - val_accuracy: 0.8235
# Epoch 6/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.3179 - accuracy: 0.8963 - val_loss: 0.3888 - val_accuracy: 0.8358
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3087 - accuracy: 0.8984 - val_loss: 0.4018 - val_accuracy: 0.8333
# Epoch 8/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.3065 - accuracy: 0.8957 - val_loss: 0.4044 - val_accuracy: 0.8333
# Epoch 9/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2997 - accuracy: 0.9039 - val_loss: 0.4111 - val_accuracy: 0.8284
# Epoch 10/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2910 - accuracy: 0.9036 - val_loss: 0.3973 - val_accuracy: 0.8309
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3973 - accuracy: 0.8309
# Split : === :  4
# Epoch 1/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.3135 - accuracy: 0.8938 - val_loss: 0.1789 - val_accuracy: 0.9363
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3061 - accuracy: 0.8946 - val_loss: 0.1799 - val_accuracy: 0.9338
# Epoch 3/10
# 115/115 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.89 - 5s 40ms/step - loss: 0.3004 - accuracy: 0.8995 - val_loss: 0.1770 - val_accuracy: 0.9338
# Epoch 4/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2916 - accuracy: 0.8984 - val_loss: 0.1829 - val_accuracy: 0.9338
# Epoch 5/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2893 - accuracy: 0.9009 - val_loss: 0.1752 - val_accuracy: 0.9338
# Epoch 6/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.3313 - accuracy: 0.9012 - val_loss: 0.1717 - val_accuracy: 0.9338
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2882 - accuracy: 0.9031 - val_loss: 0.1743 - val_accuracy: 0.9338
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2791 - accuracy: 0.9044 - val_loss: 0.1758 - val_accuracy: 0.9289
# Epoch 9/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.3002 - accuracy: 0.9036 - val_loss: 0.1729 - val_accuracy: 0.9289
# Epoch 10/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.3245 - accuracy: 0.9063 - val_loss: 0.1713 - val_accuracy: 0.9338
# 13/13 [==============================] - 0s 11ms/step - loss: 0.1713 - accuracy: 0.9338
# Split : === :  5
# Epoch 1/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2642 - accuracy: 0.9077 - val_loss: 0.3126 - val_accuracy: 0.8971
# Epoch 2/10
# 115/115 [==============================] - 4s 38ms/step - loss: 0.2434 - accuracy: 0.9112 - val_loss: 0.3256 - val_accuracy: 0.8873
# Epoch 3/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.3625 - accuracy: 0.9121 - val_loss: 0.3383 - val_accuracy: 0.8873
# Epoch 4/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2367 - accuracy: 0.9107 - val_loss: 0.3484 - val_accuracy: 0.8725
# Epoch 5/10
# 115/115 [==============================] - 4s 35ms/step - loss: 0.2374 - accuracy: 0.9115 - val_loss: 0.3683 - val_accuracy: 0.8505
# Epoch 6/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2450 - accuracy: 0.9121 - val_loss: 0.3808 - val_accuracy: 0.8554
# Epoch 7/10
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2330 - accuracy: 0.9151 - val_loss: 0.3998 - val_accuracy: 0.8456
# Epoch 8/10
# 115/115 [==============================] - 7s 59ms/step - loss: 0.2293 - accuracy: 0.9161 - val_loss: 0.4200 - val_accuracy: 0.8382
# Epoch 9/10
# 115/115 [==============================] - 6s 52ms/step - loss: 0.2226 - accuracy: 0.9170 - val_loss: 0.4156 - val_accuracy: 0.8407
# Epoch 10/10
# 115/115 [==============================] - 5s 43ms/step - loss: 0.2200 - accuracy: 0.9170 - val_loss: 0.4317 - val_accuracy: 0.8382
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4317 - accuracy: 0.8382
# Split : === :  6
# Epoch 1/10
# 115/115 [==============================] - 5s 45ms/step - loss: 0.2937 - accuracy: 0.9077 - val_loss: 0.2582 - val_accuracy: 0.8971
# Epoch 2/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.2314 - accuracy: 0.9151 - val_loss: 0.2682 - val_accuracy: 0.8922
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2280 - accuracy: 0.9159 - val_loss: 0.2579 - val_accuracy: 0.9020
# Epoch 4/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3037 - accuracy: 0.9164 - val_loss: 0.2768 - val_accuracy: 0.8946
# Epoch 5/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2216 - accuracy: 0.9191 - val_loss: 0.2747 - val_accuracy: 0.8922
# Epoch 6/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2185 - accuracy: 0.9191 - val_loss: 0.2871 - val_accuracy: 0.8897
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2190 - accuracy: 0.9181 - val_loss: 0.2810 - val_accuracy: 0.8873
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2140 - accuracy: 0.9205 - val_loss: 0.2854 - val_accuracy: 0.8799
# Epoch 9/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2117 - accuracy: 0.9210 - val_loss: 0.3010 - val_accuracy: 0.8725
# Epoch 10/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.2249 - accuracy: 0.9197 - val_loss: 0.5866 - val_accuracy: 0.8603
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5866 - accuracy: 0.8603
# Split : === :  7
# Epoch 1/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.3135 - accuracy: 0.9069 - val_loss: 0.4107 - val_accuracy: 0.8873
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2266 - accuracy: 0.9156 - val_loss: 0.2998 - val_accuracy: 0.8946
# Epoch 3/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2945 - accuracy: 0.9178 - val_loss: 0.3006 - val_accuracy: 0.8971
# Epoch 4/10
# 115/115 [==============================] - 5s 44ms/step - loss: 0.2189 - accuracy: 0.9178 - val_loss: 0.3024 - val_accuracy: 0.8946
# Epoch 5/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2104 - accuracy: 0.9175 - val_loss: 0.3038 - val_accuracy: 0.8971
# Epoch 6/10
# 115/115 [==============================] - 5s 46ms/step - loss: 0.2069 - accuracy: 0.9183 - val_loss: 0.3047 - val_accuracy: 0.8971
# Epoch 7/10
# 115/115 [==============================] - 5s 45ms/step - loss: 0.2088 - accuracy: 0.9170 - val_loss: 0.3037 - val_accuracy: 0.8971
# Epoch 8/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2051 - accuracy: 0.9197 - val_loss: 0.3026 - val_accuracy: 0.8971
# Epoch 9/10
# 115/115 [==============================] - 4s 37ms/step - loss: 0.2122 - accuracy: 0.9191 - val_loss: 0.3048 - val_accuracy: 0.8971
# Epoch 10/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2025 - accuracy: 0.9191 - val_loss: 0.3105 - val_accuracy: 0.8971
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3105 - accuracy: 0.8971
# Split : === :  8
# Epoch 1/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2211 - accuracy: 0.9159 - val_loss: 0.1655 - val_accuracy: 0.9265
# Epoch 2/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2165 - accuracy: 0.9164 - val_loss: 0.1654 - val_accuracy: 0.9265
# Epoch 3/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.2150 - accuracy: 0.9178 - val_loss: 0.1672 - val_accuracy: 0.9265
# Epoch 4/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2153 - accuracy: 0.9172 - val_loss: 0.1678 - val_accuracy: 0.9265
# Epoch 5/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2142 - accuracy: 0.9167 - val_loss: 0.1720 - val_accuracy: 0.9265
# Epoch 6/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2436 - accuracy: 0.9183 - val_loss: 0.1693 - val_accuracy: 0.9265
# Epoch 7/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.2102 - accuracy: 0.9183 - val_loss: 0.1680 - val_accuracy: 0.9265
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.2113 - accuracy: 0.9189 - val_loss: 0.1691 - val_accuracy: 0.9289
# Epoch 9/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2122 - accuracy: 0.9189 - val_loss: 0.1691 - val_accuracy: 0.9265
# Epoch 10/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.2077 - accuracy: 0.9194 - val_loss: 0.1728 - val_accuracy: 0.9216
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1728 - accuracy: 0.9216
# Split : === :  9
# Epoch 1/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2049 - accuracy: 0.9197 - val_loss: 0.1913 - val_accuracy: 0.9167
# Epoch 2/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.2082 - accuracy: 0.9200 - val_loss: 0.1905 - val_accuracy: 0.9191
# Epoch 3/10
# 115/115 [==============================] - 5s 44ms/step - loss: 0.2025 - accuracy: 0.9227 - val_loss: 0.1940 - val_accuracy: 0.9167
# Epoch 4/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2021 - accuracy: 0.9219 - val_loss: 0.1905 - val_accuracy: 0.9191
# Epoch 5/10
# 115/115 [==============================] - 5s 44ms/step - loss: 0.1985 - accuracy: 0.9221 - val_loss: 0.1915 - val_accuracy: 0.9191
# Epoch 6/10
# 115/115 [==============================] - 5s 45ms/step - loss: 0.2026 - accuracy: 0.9205 - val_loss: 0.1920 - val_accuracy: 0.9191
# Epoch 7/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.1998 - accuracy: 0.9227 - val_loss: 0.1911 - val_accuracy: 0.9191
# Epoch 8/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.1971 - accuracy: 0.9230 - val_loss: 0.1935 - val_accuracy: 0.9167
# Epoch 9/10
# 115/115 [==============================] - 6s 51ms/step - loss: 0.2724 - accuracy: 0.9216 - val_loss: 0.1933 - val_accuracy: 0.9191
# Epoch 10/10
# 115/115 [==============================] - 5s 43ms/step - loss: 0.2007 - accuracy: 0.9213 - val_loss: 0.2044 - val_accuracy: 0.9118
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2044 - accuracy: 0.9118
# Split : === :  10
# Epoch 1/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.2025 - accuracy: 0.9186 - val_loss: 0.2032 - val_accuracy: 0.9363
# Epoch 2/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2037 - accuracy: 0.9189 - val_loss: 0.1989 - val_accuracy: 0.9387
# Epoch 3/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.1982 - accuracy: 0.9205 - val_loss: 0.2064 - val_accuracy: 0.9289
# Epoch 4/10
# 115/115 [==============================] - 5s 44ms/step - loss: 0.2076 - accuracy: 0.9202 - val_loss: 0.2294 - val_accuracy: 0.9387
# Epoch 5/10
# 115/115 [==============================] - 5s 41ms/step - loss: 0.2176 - accuracy: 0.9216 - val_loss: 0.1945 - val_accuracy: 0.9363
# Epoch 6/10
# 115/115 [==============================] - 5s 42ms/step - loss: 0.1941 - accuracy: 0.9227 - val_loss: 0.1998 - val_accuracy: 0.9363
# Epoch 7/10
# 115/115 [==============================] - 5s 43ms/step - loss: 0.1995 - accuracy: 0.9197 - val_loss: 0.2035 - val_accuracy: 0.9363
# Epoch 8/10
# 115/115 [==============================] - 5s 40ms/step - loss: 0.1936 - accuracy: 0.9227 - val_loss: 0.2100 - val_accuracy: 0.9289
# Epoch 9/10
# 115/115 [==============================] - 4s 39ms/step - loss: 0.1919 - accuracy: 0.9232 - val_loss: 0.2120 - val_accuracy: 0.9338
# Epoch 10/10
# 115/115 [==============================] - 5s 39ms/step - loss: 0.1901 - accuracy: 0.9232 - val_loss: 0.2151 - val_accuracy: 0.9289
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2151 - accuracy: 0.9289

# %%
scores = np.array(scores)
score_acc = scores[:,-1]
f1_scores = np.array(f1)
print('Normal Cross Validation with',fold, 'folds, Model : LSTM')
print('Accuracy : %0.4f' %score_acc.mean())
print('F1_score : %0.4f' %f1_scores.mean())
# Out:
# Normal Cross Validation with 10 folds, Model : LSTM
# Accuracy : 0.8692
# F1_score : 0.8692

# %%
#Per Participant Cross Validation
#Subject 1
df_sub1, df_subj_1 = sliding_window_samples(d1_s1, window_length, overlap)
data_s1 = np.array(df_sub1, dtype = float)

X_s1 = data_s1[:, : ,0:12]
y_s1 = data_s1[:, : , 12]
X_dummy, y_s1 = dim_reduction(X_s1, y_s1)

fold=4
scores, f1, matrix = stratify(X_s1,y_s1,fold)
# Out:
# Split : === :  1
# Epoch 1/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1766 - accuracy: 0.9188 - val_loss: 0.1607 - val_accuracy: 0.9518
# Epoch 2/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1921 - accuracy: 0.9122 - val_loss: 0.1471 - val_accuracy: 0.9452
# Epoch 3/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1741 - accuracy: 0.9195 - val_loss: 0.1465 - val_accuracy: 0.9452
# Epoch 4/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1740 - accuracy: 0.9195 - val_loss: 0.1488 - val_accuracy: 0.9474
# Epoch 5/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1719 - accuracy: 0.9217 - val_loss: 0.1626 - val_accuracy: 0.9452
# Epoch 6/10
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1727 - accuracy: 0.9195 - val_loss: 0.1462 - val_accuracy: 0.9474
# Epoch 7/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1721 - accuracy: 0.9181 - val_loss: 0.1531 - val_accuracy: 0.9452
# Epoch 8/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1709 - accuracy: 0.9195 - val_loss: 0.1536 - val_accuracy: 0.9496
# Epoch 9/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1708 - accuracy: 0.9203 - val_loss: 0.1482 - val_accuracy: 0.9474
# Epoch 10/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1683 - accuracy: 0.9203 - val_loss: 0.1451 - val_accuracy: 0.9474
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1451 - accuracy: 0.9474
# Split : === :  2
# Epoch 1/10
# 43/43 [==============================] - 1s 29ms/step - loss: 0.1663 - accuracy: 0.9283 - val_loss: 0.1544 - val_accuracy: 0.9254
# Epoch 2/10
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1673 - accuracy: 0.9276 - val_loss: 0.1614 - val_accuracy: 0.9232
# Epoch 3/10
# 43/43 [==============================] - 1s 29ms/step - loss: 0.1647 - accuracy: 0.9268 - val_loss: 0.1556 - val_accuracy: 0.9254
# Epoch 4/10
# 43/43 [==============================] - 1s 29ms/step - loss: 0.1616 - accuracy: 0.9283 - val_loss: 0.1553 - val_accuracy: 0.9254
# Epoch 5/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1628 - accuracy: 0.9276 - val_loss: 0.1579 - val_accuracy: 0.9254
# Epoch 6/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1636 - accuracy: 0.9268 - val_loss: 0.1561 - val_accuracy: 0.9254
# Epoch 7/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1607 - accuracy: 0.9290 - val_loss: 0.1582 - val_accuracy: 0.9254
# Epoch 8/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1604 - accuracy: 0.9298 - val_loss: 0.1513 - val_accuracy: 0.9320
# Epoch 9/10
# 43/43 [==============================] - 1s 35ms/step - loss: 0.1605 - accuracy: 0.9298 - val_loss: 0.1565 - val_accuracy: 0.9254
# Epoch 10/10
# 43/43 [==============================] - 1s 35ms/step - loss: 0.1586 - accuracy: 0.9312 - val_loss: 0.1543 - val_accuracy: 0.9320
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1543 - accuracy: 0.9320
# Split : === :  3
# Epoch 1/10
# 43/43 [==============================] - 2s 36ms/step - loss: 0.1647 - accuracy: 0.9334 - val_loss: 0.1344 - val_accuracy: 0.9211
# Epoch 2/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1616 - accuracy: 0.9356 - val_loss: 0.1347 - val_accuracy: 0.9211
# Epoch 3/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1655 - accuracy: 0.9371 - val_loss: 0.1362 - val_accuracy: 0.9189
# Epoch 4/10
# 43/43 [==============================] - 1s 34ms/step - loss: 0.1598 - accuracy: 0.9349 - val_loss: 0.1354 - val_accuracy: 0.9211
# Epoch 5/10
# 43/43 [==============================] - 1s 35ms/step - loss: 0.1593 - accuracy: 0.9349 - val_loss: 0.1346 - val_accuracy: 0.9211
# Epoch 6/10
# 43/43 [==============================] - 2s 38ms/step - loss: 0.1623 - accuracy: 0.9364 - val_loss: 0.1345 - val_accuracy: 0.9211
# Epoch 7/10
# 43/43 [==============================] - 2s 39ms/step - loss: 0.2279 - accuracy: 0.9349 - val_loss: 0.1351 - val_accuracy: 0.9211
# Epoch 8/10
# 43/43 [==============================] - 2s 40ms/step - loss: 0.1601 - accuracy: 0.9349 - val_loss: 0.1356 - val_accuracy: 0.9211
# Epoch 9/10
# 43/43 [==============================] - 2s 43ms/step - loss: 0.1573 - accuracy: 0.9364 - val_loss: 0.1344 - val_accuracy: 0.9232
# Epoch 10/10
# 43/43 [==============================] - 2s 42ms/step - loss: 0.1624 - accuracy: 0.9327 - val_loss: 0.1407 - val_accuracy: 0.9167
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1407 - accuracy: 0.9167
# Split : === :  4
# Epoch 1/10
# 43/43 [==============================] - 2s 48ms/step - loss: 0.1442 - accuracy: 0.9291 - val_loss: 0.2069 - val_accuracy: 0.9165
# Epoch 2/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1347 - accuracy: 0.9364 - val_loss: 0.2073 - val_accuracy: 0.9165
# Epoch 3/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1342 - accuracy: 0.9357 - val_loss: 0.2400 - val_accuracy: 0.9165
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.1333 - accuracy: 0.9349 - val_loss: 0.2078 - val_accuracy: 0.9165
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.1414 - accuracy: 0.9342 - val_loss: 0.2150 - val_accuracy: 0.9165
# Epoch 6/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1330 - accuracy: 0.9357 - val_loss: 0.2568 - val_accuracy: 0.9187
# Epoch 7/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1311 - accuracy: 0.9364 - val_loss: 0.2408 - val_accuracy: 0.9165
# Epoch 8/10
# 43/43 [==============================] - 2s 46ms/step - loss: 0.1322 - accuracy: 0.9357 - val_loss: 0.2206 - val_accuracy: 0.9187
# Epoch 9/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1313 - accuracy: 0.9379 - val_loss: 0.2162 - val_accuracy: 0.9187
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1304 - accuracy: 0.9371 - val_loss: 0.2186 - val_accuracy: 0.9187
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2186 - accuracy: 0.9187

# %%
scores = np.array(scores)
score_acc = scores[:,-1]
f1_scores = np.array(f1)
print('SUB 1 Cross Validation with',fold, 'folds, Model : LSTM')
print('Accuracy : %0.4f' %score_acc.mean())
print('F1_score : %0.4f' %f1_scores.mean())
# Out:
# SUB 1 Cross Validation with 4 folds, Model : LSTM
# Accuracy : 0.9287
# F1_score : 0.9281

# %%
#Subject 2
df_sub2, df_subj_2 = sliding_window_samples(d2_s2, window_length, overlap)
data_s2 = np.array(df_sub2, dtype = float)

X_s2 = data_s2[:, : ,0:12]
y_s2 = data_s2[:, : , 12]
X_dummy, y_s2 = dim_reduction(X_s2,y_s2)

fold=7
scores, f1, matrix = stratify(X_s2,y_s2,fold)
# Out:
# Split : === :  1
# Epoch 1/10
# 61/61 [==============================] - 2s 27ms/step - loss: 239.4707 - accuracy: 0.8283 - val_loss: 130.5200 - val_accuracy: 0.6687
# Epoch 2/10
# 61/61 [==============================] - 2s 29ms/step - loss: 5015.1807 - accuracy: 0.8604 - val_loss: 1.5606 - val_accuracy: 0.6873
# Epoch 3/10
# 61/61 [==============================] - 3s 43ms/step - loss: 0.3045 - accuracy: 0.8961 - val_loss: 1.4794 - val_accuracy: 0.6873
# Epoch 4/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2329 - accuracy: 0.9193 - val_loss: 1.5497 - val_accuracy: 0.7090
# Epoch 5/10
# 61/61 [==============================] - 3s 43ms/step - loss: 0.1979 - accuracy: 0.9214 - val_loss: 1.6376 - val_accuracy: 0.6966
# Epoch 6/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.1779 - accuracy: 0.9349 - val_loss: 1.6464 - val_accuracy: 0.7121
# Epoch 7/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2339 - accuracy: 0.9240 - val_loss: 1.9418 - val_accuracy: 0.6471
# Epoch 8/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2199 - accuracy: 0.9219 - val_loss: 1.7221 - val_accuracy: 0.6842
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2008 - accuracy: 0.9307 - val_loss: 1.7590 - val_accuracy: 0.6842
# Epoch 10/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2272 - accuracy: 0.9230 - val_loss: 2.1018 - val_accuracy: 0.6099
# 11/11 [==============================] - 0s 16ms/step - loss: 2.1018 - accuracy: 0.6099
# Split : === :  2
# Epoch 1/10
# 61/61 [==============================] - 3s 49ms/step - loss: 0.8130 - accuracy: 0.8449 - val_loss: 0.5553 - val_accuracy: 0.8204
# Epoch 2/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.4462 - accuracy: 0.8661 - val_loss: 0.5395 - val_accuracy: 0.8328
# Epoch 3/10
# 61/61 [==============================] - 3s 44ms/step - loss: 0.3053 - accuracy: 0.8950 - val_loss: 0.4820 - val_accuracy: 0.8514
# Epoch 4/10
# 61/61 [==============================] - 3s 43ms/step - loss: 0.2612 - accuracy: 0.9105 - val_loss: 0.4500 - val_accuracy: 0.8607
# Epoch 5/10
# 61/61 [==============================] - 3s 44ms/step - loss: 0.2489 - accuracy: 0.9111 - val_loss: 0.4714 - val_accuracy: 0.8545
# Epoch 6/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2399 - accuracy: 0.9168 - val_loss: 0.4532 - val_accuracy: 0.8576
# Epoch 7/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.2247 - accuracy: 0.9188 - val_loss: 0.4611 - val_accuracy: 0.8545
# Epoch 8/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2247 - accuracy: 0.9209 - val_loss: 0.4572 - val_accuracy: 0.8545
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2159 - accuracy: 0.9245 - val_loss: 0.4626 - val_accuracy: 0.8514
# Epoch 10/10
# 61/61 [==============================] - 3s 50ms/step - loss: 0.2067 - accuracy: 0.9240 - val_loss: 0.4515 - val_accuracy: 0.8514
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4515 - accuracy: 0.8514
# Split : === :  3
# Epoch 1/10
# 61/61 [==============================] - 3s 45ms/step - loss: 0.2374 - accuracy: 0.9142 - val_loss: 0.1890 - val_accuracy: 0.9319
# Epoch 2/10
# 61/61 [==============================] - 3s 48ms/step - loss: 0.2267 - accuracy: 0.9183 - val_loss: 0.1891 - val_accuracy: 0.9319
# Epoch 3/10
# 61/61 [==============================] - 3s 45ms/step - loss: 0.2252 - accuracy: 0.9178 - val_loss: 0.1912 - val_accuracy: 0.9319
# Epoch 4/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.2161 - accuracy: 0.9204 - val_loss: 0.1917 - val_accuracy: 0.9319
# Epoch 5/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2114 - accuracy: 0.9204 - val_loss: 0.1939 - val_accuracy: 0.9319
# Epoch 6/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2113 - accuracy: 0.9188 - val_loss: 0.1916 - val_accuracy: 0.9288
# Epoch 7/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.2058 - accuracy: 0.9219 - val_loss: 0.1934 - val_accuracy: 0.9288
# Epoch 8/10
# 61/61 [==============================] - 2s 39ms/step - loss: 0.2033 - accuracy: 0.9230 - val_loss: 0.2016 - val_accuracy: 0.9257
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.1997 - accuracy: 0.9230 - val_loss: 0.1979 - val_accuracy: 0.9288
# Epoch 10/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.1959 - accuracy: 0.9230 - val_loss: 0.2013 - val_accuracy: 0.9288
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2013 - accuracy: 0.9288
# Split : === :  4
# Epoch 1/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2073 - accuracy: 0.9189 - val_loss: 0.1418 - val_accuracy: 0.9410
# Epoch 2/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.2046 - accuracy: 0.9209 - val_loss: 0.1408 - val_accuracy: 0.9379
# Epoch 3/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.2051 - accuracy: 0.9194 - val_loss: 0.1432 - val_accuracy: 0.9410
# Epoch 4/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.2005 - accuracy: 0.9199 - val_loss: 0.1398 - val_accuracy: 0.9379
# Epoch 5/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.1986 - accuracy: 0.9220 - val_loss: 0.1453 - val_accuracy: 0.9379
# Epoch 6/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.1982 - accuracy: 0.9204 - val_loss: 0.1450 - val_accuracy: 0.9379
# Epoch 7/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.1935 - accuracy: 0.9214 - val_loss: 0.1419 - val_accuracy: 0.9379
# Epoch 8/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.1881 - accuracy: 0.9245 - val_loss: 0.1468 - val_accuracy: 0.9379
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2099 - accuracy: 0.9214 - val_loss: 0.1445 - val_accuracy: 0.9379
# Epoch 10/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.2755 - accuracy: 0.9142 - val_loss: 0.3176 - val_accuracy: 0.8913
# 11/11 [==============================] - 0s 11ms/step - loss: 0.3176 - accuracy: 0.8913
# Split : === :  5
# Epoch 1/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.3221 - accuracy: 0.8873 - val_loss: 0.2432 - val_accuracy: 0.9006
# Epoch 2/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2888 - accuracy: 0.8961 - val_loss: 0.2378 - val_accuracy: 0.9006
# Epoch 3/10
# 61/61 [==============================] - 2s 39ms/step - loss: 0.2735 - accuracy: 0.9023 - val_loss: 0.2208 - val_accuracy: 0.9068
# Epoch 4/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.2643 - accuracy: 0.9023 - val_loss: 0.2296 - val_accuracy: 0.9068
# Epoch 5/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2608 - accuracy: 0.9044 - val_loss: 0.2154 - val_accuracy: 0.9068
# Epoch 6/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.2536 - accuracy: 0.9054 - val_loss: 0.2320 - val_accuracy: 0.9068
# Epoch 7/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2538 - accuracy: 0.9070 - val_loss: 0.2324 - val_accuracy: 0.9037 accuracy: 0.
# Epoch 8/10
# 61/61 [==============================] - 2s 40ms/step - loss: 0.2468 - accuracy: 0.9096 - val_loss: 0.2205 - val_accuracy: 0.9068
# Epoch 9/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2448 - accuracy: 0.9085 - val_loss: 0.2290 - val_accuracy: 0.9068
# Epoch 10/10
# 61/61 [==============================] - 2s 39ms/step - loss: 0.2447 - accuracy: 0.9085 - val_loss: 0.2285 - val_accuracy: 0.9068
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2285 - accuracy: 0.9068
# Split : === :  6
# Epoch 1/10
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2525 - accuracy: 0.9059 - val_loss: 0.1910 - val_accuracy: 0.9317
# Epoch 2/10
# 61/61 [==============================] - 2s 35ms/step - loss: 0.2405 - accuracy: 0.9059 - val_loss: 0.1872 - val_accuracy: 0.9348
# Epoch 3/10
# 61/61 [==============================] - 2s 34ms/step - loss: 0.2390 - accuracy: 0.9090 - val_loss: 0.1873 - val_accuracy: 0.9348
# Epoch 4/10
# 61/61 [==============================] - 2s 35ms/step - loss: 0.2417 - accuracy: 0.9075 - val_loss: 0.1873 - val_accuracy: 0.9348
# Epoch 5/10
# 61/61 [==============================] - 2s 35ms/step - loss: 0.2357 - accuracy: 0.9090 - val_loss: 0.1954 - val_accuracy: 0.9286
# Epoch 6/10
# 61/61 [==============================] - 2s 36ms/step - loss: 0.2382 - accuracy: 0.9085 - val_loss: 0.1904 - val_accuracy: 0.9348
# Epoch 7/10
# 61/61 [==============================] - 2s 37ms/step - loss: 0.2328 - accuracy: 0.9085 - val_loss: 0.1895 - val_accuracy: 0.9317
# Epoch 8/10
# 61/61 [==============================] - 2s 39ms/step - loss: 0.2320 - accuracy: 0.9096 - val_loss: 0.1888 - val_accuracy: 0.9317
# Epoch 9/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.2250 - accuracy: 0.9096 - val_loss: 0.1902 - val_accuracy: 0.9286
# Epoch 10/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2297 - accuracy: 0.9096 - val_loss: 0.1886 - val_accuracy: 0.9317
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1886 - accuracy: 0.9317
# Split : === :  7
# Epoch 1/10
# 61/61 [==============================] - 2s 41ms/step - loss: 0.6395 - accuracy: 0.9049 - val_loss: 0.1711 - val_accuracy: 0.9441
# Epoch 2/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.2518 - accuracy: 0.9028 - val_loss: 0.1703 - val_accuracy: 0.9441
# Epoch 3/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2471 - accuracy: 0.9059 - val_loss: 0.1717 - val_accuracy: 0.9410
# Epoch 4/10
# 61/61 [==============================] - 3s 43ms/step - loss: 0.2446 - accuracy: 0.9070 - val_loss: 0.1712 - val_accuracy: 0.9441
# Epoch 5/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.2444 - accuracy: 0.9065 - val_loss: 0.1721 - val_accuracy: 0.9410
# Epoch 6/10
# 61/61 [==============================] - 3s 41ms/step - loss: 0.2424 - accuracy: 0.9075 - val_loss: 0.1738 - val_accuracy: 0.9410
# Epoch 7/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2415 - accuracy: 0.9070 - val_loss: 0.1726 - val_accuracy: 0.9410
# Epoch 8/10
# 61/61 [==============================] - 3s 43ms/step - loss: 0.2400 - accuracy: 0.9085 - val_loss: 0.1754 - val_accuracy: 0.9410
# Epoch 9/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2394 - accuracy: 0.9090 - val_loss: 0.1790 - val_accuracy: 0.9410
# Epoch 10/10
# 61/61 [==============================] - 3s 42ms/step - loss: 0.2376 - accuracy: 0.9090 - val_loss: 0.1854 - val_accuracy: 0.9379
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1854 - accuracy: 0.9379

# %%
scores = np.array(scores)
score_acc = scores[:,-1]
f1_scores = np.array(f1)
print('SUB 2 Cross Validation with',fold, 'folds, Model : LSTM')
print('Accuracy : %0.4f' %score_acc.mean())
print('F1_score : %0.4f' %f1_scores.mean())
# Out:
# SUB 2 Cross Validation with 7 folds, Model : LSTM
# Accuracy : 0.8654
# F1_score : 0.8672
